# %%
#Import tensorflow

import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From C:\Users\Asus\anaconda3\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
#Test if GPU is found

if tf.test.gpu_device_name():
    print('GPU found')
else:
    print("No GPU found")
# Out:
# GPU found

# %%
#Autosaving every 10s

# %autosave 10
# Out:
# Autosaving every 10 seconds

# %%
#Training & Testing files

train_file = "train17.csv"
val_file = "val17.csv"
matlab_file = '1_50_17.mat'
rul_file = "rul_50_17.csv"
fleet_Rul_File = "rul17.csv"
test_file = "test17.csv"

# %%
import pandas as pd
import numpy as np
import scipy.io
import tensorflow_probability as tfp
import matplotlib as plt
import matplotlib.pyplot as plt
import pickle
import scipy.io as spio
import pickle
from tensorflow.keras import optimizers, regularizers
from tensorflow.keras.models import Sequential, model_from_json, load_model
from tensorflow.keras.layers import Dense, LSTM, Dropout, Masking
tfd = tfp.distributions

# %%
#fix random seed for reproducibility

np.random.seed(0)

# %%
#load Training & Testing files into Pandas Dataframes

train = pd.read_csv(train_file, index_col=False)
val = pd.read_csv(val_file, index_col=False)
mat = spio.loadmat(matlab_file, squeeze_me=True)
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\scipy\io\matlab\mio.py:218: MatReadWarning: Duplicate variable name "None" in stream - replacing previous with new
# Consider mio5.varmats_from_mat to split file into single variable files
#   matfile_dict = MR.get_variables(variable_names)

# %%
#Load Hyperparameters Obtained by BayesOpt

lr = mat['lr']
ep = mat['ep']
batch = mat['batch']
pad = mat['Pad']
L2 = mat['L2'] 
unit1 = mat['unit'] 
size1 = mat['size']
drop1 = mat['drop']

lr,ep,batch,pad,L2,unit1,size1,drop1
# Out:
# (0.0005025687893372792, 1e-08, 88, 303, 0.0001, 64, 364, 0.35644088162095944)

# %%
#Xtrain to Numpy multidimensional array

xtrain_cut = train.drop(['Fleet','Cycle','RUL'], axis=1)
xtrain = np.zeros((train['Fleet'].max(),pad,xtrain_cut.shape[1]))
for i in range(train['Fleet'].max()):
    df_xtrain = train.loc[train['Fleet']==i+1]
    df_xtrain = df_xtrain.drop(['Fleet','Cycle','RUL'], axis=1)
    np_xtrain = df_xtrain.values
    result = np.zeros((pad,df_xtrain.shape[1]))
    result[:np_xtrain.shape[0],:np_xtrain.shape[1]] = np_xtrain
    xtrain[i] = result
xtrain.shape
# Out:
# (100, 303, 17)

# %%
#Ytrain to Numpy multidimensional array

ytrain_cut = train[['RUL']]
ytrain = np.zeros((train['Fleet'].max(),pad,1))
for i in range(train['Fleet'].max()):
    df_ytrain = train.loc[train['Fleet']==i+1]
    df_ytrain = df_ytrain[['RUL']]
    np_ytrain = df_ytrain.values
    result = np.zeros((pad,df_ytrain.shape[1]))
    result[:np_ytrain.shape[0],:np_ytrain.shape[1]] = np_ytrain
    ytrain[i] = result
ytrain.shape
# Out:
# (100, 303, 1)

# %%
#Ytrain2 to Numpy multidimensional array - for SHAP

ytrain2 = np.zeros(train['Fleet'].max())
for i in range(train['Fleet'].max()):
    df_ytrain2 = train.loc[train['Fleet']==i+1]
    df_ytrain2 = df_ytrain2[['RUL']].values
    ytrain2[i] = df_ytrain2[0]
ytrain2.shape
# Out:
# (100,)

# %%
#Xval to Numpy multidimensional array

xval_cut = val.drop(['RUL','Fleet','Cycle'], axis=1)
xval = np.zeros((val['Fleet'].max(),pad,xval_cut.shape[1]))
for i in range(val['Fleet'].max()):
    df_xval = val.loc[val['Fleet']==i+1]
    df_xval = df_xval.drop(['Fleet','Cycle','RUL'], axis=1)
    np_xval = df_xval.values
    result = np.zeros((pad,df_xval.shape[1]))
    result[:np_xval.shape[0],:np_xval.shape[1]] = np_xval
    xval[i] = result
xval.shape
# Out:
# (100, 303, 17)

# %%
#Yval to Numpy multidimensional array - for sequential prediction 

yval_cut = val[['RUL']]
yval = np.zeros((val['Fleet'].max(),pad,1))
for i in range(val['Fleet'].max()):
    df_yval = val.loc[val['Fleet']==i+1]
    df_yval = df_yval[['RUL']]
    np_yval = df_yval.values
    result = np.zeros((pad,df_yval.shape[1]))
    result[:np_yval.shape[0],:np_yval.shape[1]] = np_yval
    yval[i] = result
yval.shape
# Out:
# (100, 303, 1)

# %%
#Yval2 to Numpy multidimensional array - for SHAP 

yval2 = np.zeros(train['Fleet'].max())
for i in range(train['Fleet'].max()):
    df_yval2 = train.loc[train['Fleet']==i+1]
    df_yval2 = df_yval2[['RUL']].values
    yval2[i] = df_yval2[0]
yval2.shape
# Out:
# (100,)

# %%
#xtest to Numpy multidimensional array 

test = pd.read_csv(test_file, index_col=False)
xtest_cut = test.drop(['Fleet','Cycle'], axis=1)
xtest = np.zeros((test['Fleet'].max(),pad,xtest_cut.shape[1]))
for i in range(test['Fleet'].max()):
    df_xtest = test.loc[test['Fleet']==i+1]
    df_xtest = df_xtest.drop(['Fleet','Cycle'], axis=1)
    np_xtest = df_xtest.values
    result = np.zeros((pad,df_xtest.shape[1]))
    result[:np_xtest.shape[0],:np_xtest.shape[1]] = np_xtest
    xtest[i] = result

# %%
#Verify shapes of array

xtrain.shape,ytrain.shape, ytrain2.shape,xval.shape,yval.shape,yval2.shape,xtest.shape
# Out:
# ((100, 303, 17),
#  (100, 303, 1),
#  (100,),
#  (100, 303, 17),
#  (100, 303, 1),
#  (100,),
#  (100, 303, 17))

# %%
xtrain = xtrain.astype(np.float32)
ytrain = ytrain.astype(np.float32)
ytrain2 = ytrain2.astype(np.float32)
xval = xval.astype(np.float32)
yval = yval.astype(np.float32)
yval2 = yval2.astype(np.float32)
xtest = xtest.astype(np.float32)

# %%
#Set ytrain,yval for 3 outputs

x_train = xtrain
y_train = [ytrain,ytrain]
x_val = xval
y_val = [yval,yval]
x_test = xtest

# %%
from tensorflow.keras import layers
from tensorflow.keras import activations
from tensorflow.keras import callbacks
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback,ReduceLROnPlateau
from tensorflow.keras.layers import Flatten, Reshape
import warnings
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input, Lambda, concatenate
from tensorflow.keras.models import Model
from IPython.display import display

# %%
# Define trainable prior

def posterior_mean_field(kernel_size, bias_size=0, dtype=None):
  n = kernel_size + bias_size
  c = np.log(np.expm1(1.))
  return tf.keras.Sequential([
      tfp.layers.VariableLayer(2 * n, dtype=dtype),
      tfp.layers.DistributionLambda(lambda t: tfd.Independent(
          tfd.Normal(loc=t[..., :n],
                     scale=1e-5 + tf.nn.softplus(c + t[..., n:])),
          reinterpreted_batch_ndims=1)),
  ])

#Specify the prior over `keras.layers.Dense` `kernel` and `bias`.
def prior_trainable(kernel_size, bias_size=0, dtype=None):
  n = kernel_size + bias_size
  return tf.keras.Sequential([
      tfp.layers.VariableLayer(n, dtype=dtype),
      tfp.layers.DistributionLambda(lambda t: tfd.Independent(
          tfd.Normal(loc=t, scale=1),
          reinterpreted_batch_ndims=1)),
  ])

# %%
#Define probabilistic LSTM

#LSTM layers

inputs = tf.keras.Input(shape=(303,17),dtype='float32')
layer1 = LSTM(unit1,return_sequences = True)(inputs)
layer2 = Dense(size1)(layer1)

#Output 1 = Aleatoric output layer

layer3 = Dense(1+1)(layer2)
layer4 = tfp.layers.DistributionLambda(lambda t: tfd.Normal(loc=t[..., :1],scale=1e-3 + tf.math.softplus(0.05 * t[..., 1:])),name='out1')(layer3) #aleatoric

#Output 2 = Epistemic output layer

layer5 = tfp.layers.DenseVariational(1, posterior_mean_field, prior_trainable)(layer2)
layer6 = tfp.layers.DistributionLambda(lambda t: tfd.Normal(loc=t, scale=1),name = 'out2')(layer5)

model = tf.keras.Model(inputs=inputs, outputs=[layer4,layer6])
model.summary()
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 303, 17)]    0
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 303, 64)      20992       input_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 303, 364)     23660       lstm[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 303, 2)       730         dense[0][0]
# __________________________________________________________________________________________________
# dense_variational (DenseVariati (None, 303, 1)       1095        dense[0][0]
# __________________________________________________________________________________________________
# out1 (DistributionLambda)       ((None, 303, 1), (No 0           dense_1[0][0]
# __________________________________________________________________________________________________
# out2 (DistributionLambda)       ((None, 303, 1), (No 0           dense_variational[0][0]
# ==================================================================================================
# Total params: 46,477
# Trainable params: 46,477
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#Define directory for best weights checkpoint

import os
checkpoint_path = "C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint/1_50_17_ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

#Callback for best weights checkpoint

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    verbose = 1)

# %%
#Compile model

optimizers.Adam(learning_rate=lr, beta_1 = 0.9,beta_2 = 0.999, epsilon = ep, amsgrad = False, name = "Adam")
negloglik = lambda y, rv_y: -rv_y.log_prob(y)
model.compile(loss = {'out1': negloglik,'out2': negloglik},loss_weights=[0.5,0.5],optimizer= 'Adam')

# %%
#Set Tensorboard  

# %load_ext tensorboard
import tensorboard
tensorboard.__version__
from datetime import datetime
from tensorflow import keras
#Define the Keras TensorBoard callback.
logdir="logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)

# %%
#Run training

history = model.fit(x_train, y_train, validation_data = (x_val, y_val), epochs = 10000, batch_size  = batch, verbose = 0, callbacks=[model_checkpoint_callback,tensorboard_callback])
# Out:
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2028s vs `on_train_batch_end` time: 0.3313s). Check your callbacks.
# WARNING:tensorflow:From C:\Users\Asus\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_v1.py:2048: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
#
# Epoch 00001: val_loss improved from inf to 210.83169, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00002: val_loss did not improve from 210.83169
#
# Epoch 00003: val_loss improved from 210.83169 to 210.45594, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00004: val_loss did not improve from 210.45594
#
# Epoch 00005: val_loss improved from 210.45594 to 207.60121, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00006: val_loss improved from 207.60121 to 190.85873, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00007: val_loss did not improve from 190.85873
#
# Epoch 00008: val_loss improved from 190.85873 to 188.98052, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00009: val_loss improved from 188.98052 to 181.99776, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00010: val_loss improved from 181.99776 to 159.53533, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00011: val_loss improved from 159.53533 to 152.26162, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00012: val_loss improved from 152.26162 to 147.27465, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00013: val_loss did not improve from 147.27465
#
# Epoch 00014: val_loss did not improve from 147.27465
#
# Epoch 00015: val_loss did not improve from 147.27465
#
# Epoch 00016: val_loss improved from 147.27465 to 128.92414, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00017: val_loss improved from 128.92414 to 122.74832, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00018: val_loss did not improve from 122.74832
#
# Epoch 00019: val_loss did not improve from 122.74832
#
# Epoch 00020: val_loss did not improve from 122.74832
#
# Epoch 00021: val_loss did not improve from 122.74832
#
# Epoch 00022: val_loss did not improve from 122.74832
#
# Epoch 00023: val_loss did not improve from 122.74832
#
# Epoch 00024: val_loss improved from 122.74832 to 113.83441, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00025: val_loss did not improve from 113.83441
#
# Epoch 00026: val_loss did not improve from 113.83441
#
# Epoch 00027: val_loss improved from 113.83441 to 112.26285, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00028: val_loss did not improve from 112.26285
#
# Epoch 00029: val_loss did not improve from 112.26285
#
# Epoch 00030: val_loss did not improve from 112.26285
#
# Epoch 00031: val_loss improved from 112.26285 to 88.40296, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00032: val_loss did not improve from 88.40296
#
# Epoch 00033: val_loss improved from 88.40296 to 57.67787, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00034: val_loss did not improve from 57.67787
#
# Epoch 00035: val_loss did not improve from 57.67787
#
# Epoch 00036: val_loss improved from 57.67787 to 50.29878, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00037: val_loss improved from 50.29878 to 44.66406, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00038: val_loss did not improve from 44.66406
#
# Epoch 00039: val_loss did not improve from 44.66406
#
# Epoch 00040: val_loss did not improve from 44.66406
#
# Epoch 00041: val_loss did not improve from 44.66406
#
# Epoch 00042: val_loss did not improve from 44.66406
#
# Epoch 00043: val_loss improved from 44.66406 to 39.66925, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00044: val_loss improved from 39.66925 to 38.75508, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00045: val_loss did not improve from 38.75508
#
# Epoch 00046: val_loss did not improve from 38.75508
#
# Epoch 00047: val_loss did not improve from 38.75508
#
# Epoch 00048: val_loss did not improve from 38.75508
#
# Epoch 00049: val_loss did not improve from 38.75508
#
# Epoch 00050: val_loss did not improve from 38.75508
#
# Epoch 00051: val_loss did not improve from 38.75508
#
# Epoch 00052: val_loss did not improve from 38.75508
#
# Epoch 00053: val_loss did not improve from 38.75508
#
# Epoch 00054: val_loss did not improve from 38.75508
#
# Epoch 00055: val_loss did not improve from 38.75508
#
# Epoch 00056: val_loss did not improve from 38.75508
#
# Epoch 00057: val_loss did not improve from 38.75508
#
# Epoch 00058: val_loss improved from 38.75508 to 34.24705, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00059: val_loss did not improve from 34.24705
#
# Epoch 00060: val_loss did not improve from 34.24705
#
# Epoch 00061: val_loss did not improve from 34.24705
#
# Epoch 00062: val_loss did not improve from 34.24705
#
# Epoch 00063: val_loss did not improve from 34.24705
#
# Epoch 00064: val_loss improved from 34.24705 to 33.91833, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00065: val_loss did not improve from 33.91833
#
# Epoch 00066: val_loss did not improve from 33.91833
#
# Epoch 00067: val_loss did not improve from 33.91833
#
# Epoch 00068: val_loss did not improve from 33.91833
#
# Epoch 00069: val_loss did not improve from 33.91833
#
# Epoch 00070: val_loss did not improve from 33.91833
#
# Epoch 00071: val_loss did not improve from 33.91833
#
# Epoch 00072: val_loss did not improve from 33.91833
#
# Epoch 00073: val_loss did not improve from 33.91833
#
# Epoch 00074: val_loss improved from 33.91833 to 31.66250, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00075: val_loss improved from 31.66250 to 30.02879, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00076: val_loss did not improve from 30.02879
#
# Epoch 00077: val_loss did not improve from 30.02879
#
# Epoch 00078: val_loss did not improve from 30.02879
#
# Epoch 00079: val_loss did not improve from 30.02879
#
# Epoch 00080: val_loss improved from 30.02879 to 20.98762, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00081: val_loss did not improve from 20.98762
#
# Epoch 00082: val_loss did not improve from 20.98762
#
# Epoch 00083: val_loss did not improve from 20.98762
#
# Epoch 00084: val_loss did not improve from 20.98762
#
# Epoch 00085: val_loss did not improve from 20.98762
#
# Epoch 00086: val_loss did not improve from 20.98762
#
# Epoch 00087: val_loss did not improve from 20.98762
#
# Epoch 00088: val_loss did not improve from 20.98762
#
# Epoch 00089: val_loss improved from 20.98762 to 20.79928, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00090: val_loss did not improve from 20.79928
#
# Epoch 00091: val_loss did not improve from 20.79928
#
# Epoch 00092: val_loss did not improve from 20.79928
#
# Epoch 00093: val_loss did not improve from 20.79928
#
# Epoch 00094: val_loss did not improve from 20.79928
#
# Epoch 00095: val_loss did not improve from 20.79928
#
# Epoch 00096: val_loss did not improve from 20.79928
#
# Epoch 00097: val_loss did not improve from 20.79928
#
# Epoch 00098: val_loss did not improve from 20.79928
#
# Epoch 00099: val_loss did not improve from 20.79928
#
# Epoch 00100: val_loss did not improve from 20.79928
# Epoch 00101: val_loss did not improve from 20.79928
#
# Epoch 00102: val_loss did not improve from 20.79928
#
# Epoch 00103: val_loss did not improve from 20.79928
#
# Epoch 00104: val_loss did not improve from 20.79928
#
# Epoch 00105: val_loss did not improve from 20.79928
#
# Epoch 00106: val_loss did not improve from 20.79928
#
# Epoch 00107: val_loss did not improve from 20.79928
#
# Epoch 00108: val_loss did not improve from 20.79928
#
# Epoch 00109: val_loss did not improve from 20.79928
#
# Epoch 00110: val_loss did not improve from 20.79928
#
# Epoch 00111: val_loss did not improve from 20.79928
#
# Epoch 00112: val_loss did not improve from 20.79928
#
# Epoch 00113: val_loss did not improve from 20.79928
#
# Epoch 00114: val_loss did not improve from 20.79928
#
# Epoch 00115: val_loss improved from 20.79928 to 17.76151, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00116: val_loss did not improve from 17.76151
#
# Epoch 00117: val_loss did not improve from 17.76151
#
# Epoch 00118: val_loss did not improve from 17.76151
#
# Epoch 00119: val_loss did not improve from 17.76151
#
# Epoch 00120: val_loss did not improve from 17.76151
#
# Epoch 00121: val_loss did not improve from 17.76151
#
# Epoch 00122: val_loss did not improve from 17.76151
#
# Epoch 00123: val_loss did not improve from 17.76151
#
# Epoch 00124: val_loss did not improve from 17.76151
#
# Epoch 00125: val_loss did not improve from 17.76151
#
# Epoch 00126: val_loss did not improve from 17.76151
#
# Epoch 00127: val_loss did not improve from 17.76151
#
# Epoch 00128: val_loss did not improve from 17.76151
#
# Epoch 00129: val_loss did not improve from 17.76151
#
# Epoch 00130: val_loss did not improve from 17.76151
#
# Epoch 00131: val_loss did not improve from 17.76151
#
# Epoch 00132: val_loss did not improve from 17.76151
#
# Epoch 00133: val_loss did not improve from 17.76151
#
# Epoch 00134: val_loss did not improve from 17.76151
#
# Epoch 00135: val_loss did not improve from 17.76151
#
# Epoch 00136: val_loss did not improve from 17.76151
#
# Epoch 00137: val_loss did not improve from 17.76151
#
# Epoch 00138: val_loss improved from 17.76151 to 17.04835, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00139: val_loss did not improve from 17.04835
#
# Epoch 00140: val_loss did not improve from 17.04835
#
# Epoch 00141: val_loss did not improve from 17.04835
#
# Epoch 00142: val_loss did not improve from 17.04835
#
# Epoch 00143: val_loss did not improve from 17.04835
#
# Epoch 00144: val_loss improved from 17.04835 to 14.27002, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00145: val_loss did not improve from 14.27002
#
# Epoch 00146: val_loss did not improve from 14.27002
#
# Epoch 00147: val_loss did not improve from 14.27002
#
# Epoch 00148: val_loss did not improve from 14.27002
#
# Epoch 00149: val_loss did not improve from 14.27002
#
# Epoch 00150: val_loss did not improve from 14.27002
#
# Epoch 00151: val_loss did not improve from 14.27002
#
# Epoch 00152: val_loss did not improve from 14.27002
#
# Epoch 00153: val_loss did not improve from 14.27002
#
# Epoch 00154: val_loss did not improve from 14.27002
#
# Epoch 00155: val_loss did not improve from 14.27002
#
# Epoch 00156: val_loss did not improve from 14.27002
#
# Epoch 00157: val_loss did not improve from 14.27002
#
# Epoch 00158: val_loss did not improve from 14.27002
#
# Epoch 00159: val_loss did not improve from 14.27002
#
# Epoch 00160: val_loss did not improve from 14.27002
#
# Epoch 00161: val_loss did not improve from 14.27002
#
# Epoch 00162: val_loss did not improve from 14.27002
#
# Epoch 00163: val_loss did not improve from 14.27002
#
# Epoch 00164: val_loss did not improve from 14.27002
#
# Epoch 00165: val_loss did not improve from 14.27002
#
# Epoch 00166: val_loss did not improve from 14.27002
#
# Epoch 00167: val_loss did not improve from 14.27002
#
# Epoch 00168: val_loss did not improve from 14.27002
#
# Epoch 00169: val_loss did not improve from 14.27002
#
# Epoch 00170: val_loss improved from 14.27002 to 13.96584, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00171: val_loss did not improve from 13.96584
#
# Epoch 00172: val_loss did not improve from 13.96584
#
# Epoch 00173: val_loss did not improve from 13.96584
#
# Epoch 00174: val_loss did not improve from 13.96584
#
# Epoch 00175: val_loss did not improve from 13.96584
#
# Epoch 00176: val_loss did not improve from 13.96584
#
# Epoch 00177: val_loss did not improve from 13.96584
#
# Epoch 00178: val_loss did not improve from 13.96584
#
# Epoch 00179: val_loss did not improve from 13.96584
#
# Epoch 00180: val_loss did not improve from 13.96584
#
# Epoch 00181: val_loss did not improve from 13.96584
#
# Epoch 00182: val_loss did not improve from 13.96584
#
# Epoch 00183: val_loss did not improve from 13.96584
#
# Epoch 00184: val_loss did not improve from 13.96584
#
# Epoch 00185: val_loss did not improve from 13.96584
#
# Epoch 00186: val_loss did not improve from 13.96584
#
# Epoch 00187: val_loss improved from 13.96584 to 13.85138, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00188: val_loss did not improve from 13.85138
#
# Epoch 00189: val_loss did not improve from 13.85138
#
# Epoch 00190: val_loss did not improve from 13.85138
#
# Epoch 00191: val_loss did not improve from 13.85138
#
# Epoch 00192: val_loss did not improve from 13.85138
#
# Epoch 00193: val_loss did not improve from 13.85138
#
# Epoch 00194: val_loss did not improve from 13.85138
#
# Epoch 00195: val_loss did not improve from 13.85138
#
# Epoch 00196: val_loss did not improve from 13.85138
#
# Epoch 00197: val_loss did not improve from 13.85138
#
# Epoch 00198: val_loss did not improve from 13.85138
#
# Epoch 00199: val_loss did not improve from 13.85138
#
# Epoch 00200: val_loss improved from 13.85138 to 13.52777, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00201: val_loss did not improve from 13.52777
#
# Epoch 00202: val_loss did not improve from 13.52777
#
# Epoch 00203: val_loss did not improve from 13.52777
#
# Epoch 00204: val_loss improved from 13.52777 to 13.02687, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00205: val_loss improved from 13.02687 to 11.97475, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00206: val_loss did not improve from 11.97475
#
# Epoch 00207: val_loss did not improve from 11.97475
#
# Epoch 00208: val_loss did not improve from 11.97475
#
# Epoch 00209: val_loss did not improve from 11.97475
#
# Epoch 00210: val_loss did not improve from 11.97475
#
# Epoch 00211: val_loss did not improve from 11.97475
#
# Epoch 00212: val_loss did not improve from 11.97475
#
# Epoch 00213: val_loss improved from 11.97475 to 11.14667, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00214: val_loss did not improve from 11.14667
#
# Epoch 00215: val_loss did not improve from 11.14667
#
# Epoch 00216: val_loss did not improve from 11.14667
#
# Epoch 00217: val_loss did not improve from 11.14667
#
# Epoch 00218: val_loss did not improve from 11.14667
#
# Epoch 00219: val_loss did not improve from 11.14667
#
# Epoch 00220: val_loss did not improve from 11.14667
#
# Epoch 00221: val_loss did not improve from 11.14667
#
# Epoch 00222: val_loss did not improve from 11.14667
#
# Epoch 00223: val_loss did not improve from 11.14667
#
# Epoch 00224: val_loss did not improve from 11.14667
#
# Epoch 00225: val_loss did not improve from 11.14667
#
# Epoch 00226: val_loss did not improve from 11.14667
#
# Epoch 00227: val_loss did not improve from 11.14667
#
# Epoch 00228: val_loss did not improve from 11.14667
#
# Epoch 00229: val_loss did not improve from 11.14667
#
# Epoch 00230: val_loss did not improve from 11.14667
#
# Epoch 00231: val_loss did not improve from 11.14667
#
# Epoch 00232: val_loss did not improve from 11.14667
#
# Epoch 00233: val_loss did not improve from 11.14667
#
# Epoch 00234: val_loss did not improve from 11.14667
#
# Epoch 00235: val_loss did not improve from 11.14667
#
# Epoch 00236: val_loss did not improve from 11.14667
#
# Epoch 00237: val_loss did not improve from 11.14667
#
# Epoch 00238: val_loss improved from 11.14667 to 10.45710, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
# Epoch 00239: val_loss did not improve from 10.45710
#
# Epoch 00240: val_loss did not improve from 10.45710
#
# Epoch 00241: val_loss did not improve from 10.45710
#
# Epoch 00242: val_loss did not improve from 10.45710
#
# Epoch 00243: val_loss did not improve from 10.45710
#
# Epoch 00244: val_loss did not improve from 10.45710
#
# Epoch 00245: val_loss did not improve from 10.45710
#
# Epoch 00246: val_loss did not improve from 10.45710
#
# Epoch 00247: val_loss did not improve from 10.45710
#
# Epoch 00248: val_loss did not improve from 10.45710
#
# Epoch 00249: val_loss did not improve from 10.45710
#
# Epoch 00250: val_loss did not improve from 10.45710
#
# Epoch 00251: val_loss did not improve from 10.45710
#
# Epoch 00252: val_loss did not improve from 10.45710
#
# Epoch 00253: val_loss did not improve from 10.45710
#
# Epoch 00254: val_loss did not improve from 10.45710
#
# Epoch 00255: val_loss did not improve from 10.45710
#
# Epoch 00256: val_loss did not improve from 10.45710
#
# Epoch 00257: val_loss did not improve from 10.45710
#
# Epoch 00258: val_loss did not improve from 10.45710
#
# Epoch 00259: val_loss did not improve from 10.45710
#
# Epoch 00260: val_loss did not improve from 10.45710
#
# Epoch 00261: val_loss did not improve from 10.45710
#
# Epoch 00262: val_loss did not improve from 10.45710
#
# Epoch 00263: val_loss did not improve from 10.45710
#
# Epoch 00264: val_loss did not improve from 10.45710
#
# Epoch 00265: val_loss did not improve from 10.45710
#
# Epoch 00266: val_loss did not improve from 10.45710
#
# Epoch 00267: val_loss did not improve from 10.45710
#
# Epoch 00268: val_loss did not improve from 10.45710
#
# Epoch 00269: val_loss did not improve from 10.45710
#
# Epoch 00270: val_loss did not improve from 10.45710
#
# Epoch 00271: val_loss did not improve from 10.45710
#
# Epoch 00272: val_loss did not improve from 10.45710
#
# Epoch 00273: val_loss did not improve from 10.45710
#
# Epoch 00274: val_loss did not improve from 10.45710
#
# Epoch 00275: val_loss did not improve from 10.45710
#
# Epoch 00276: val_loss did not improve from 10.45710
#
# Epoch 00277: val_loss did not improve from 10.45710
#
# Epoch 00278: val_loss did not improve from 10.45710
#
# Epoch 00279: val_loss did not improve from 10.45710
#
# Epoch 00280: val_loss did not improve from 10.45710
#
# Epoch 00281: val_loss did not improve from 10.45710
#
# Epoch 00282: val_loss did not improve from 10.45710
#
# Epoch 00283: val_loss did not improve from 10.45710
#
# Epoch 00284: val_loss did not improve from 10.45710
#
# Epoch 00285: val_loss did not improve from 10.45710
#
# Epoch 00286: val_loss did not improve from 10.45710
#
# Epoch 00287: val_loss did not improve from 10.45710
#
# Epoch 00288: val_loss did not improve from 10.45710
#
# Epoch 00289: val_loss did not improve from 10.45710
#
# Epoch 00290: val_loss did not improve from 10.45710
#
# Epoch 00291: val_loss did not improve from 10.45710
#
# Epoch 00292: val_loss did not improve from 10.45710
#
# Epoch 00293: val_loss did not improve from 10.45710
#
# Epoch 00294: val_loss did not improve from 10.45710
#
# Epoch 00295: val_loss did not improve from 10.45710
#
# Epoch 00296: val_loss did not improve from 10.45710
#
# Epoch 00297: val_loss did not improve from 10.45710
#
# Epoch 00298: val_loss did not improve from 10.45710
#
# Epoch 00299: val_loss improved from 10.45710 to 9.71248, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00300: val_loss did not improve from 9.71248
#
# Epoch 00301: val_loss improved from 9.71248 to 9.54630, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00302: val_loss did not improve from 9.54630
#
# Epoch 00303: val_loss did not improve from 9.54630
#
# Epoch 00304: val_loss did not improve from 9.54630
#
# Epoch 00305: val_loss did not improve from 9.54630
#
# Epoch 00306: val_loss did not improve from 9.54630
#
# Epoch 00307: val_loss did not improve from 9.54630
#
# Epoch 00308: val_loss did not improve from 9.54630
#
# Epoch 00309: val_loss did not improve from 9.54630
#
# Epoch 00310: val_loss did not improve from 9.54630
#
# Epoch 00311: val_loss did not improve from 9.54630
#
# Epoch 00312: val_loss did not improve from 9.54630
#
# Epoch 00313: val_loss did not improve from 9.54630
#
# Epoch 00314: val_loss did not improve from 9.54630
#
# Epoch 00315: val_loss did not improve from 9.54630
#
# Epoch 00316: val_loss did not improve from 9.54630
#
# Epoch 00317: val_loss did not improve from 9.54630
#
# Epoch 00318: val_loss did not improve from 9.54630
#
# Epoch 00319: val_loss did not improve from 9.54630
#
# Epoch 00320: val_loss did not improve from 9.54630
#
# Epoch 00321: val_loss did not improve from 9.54630
#
# Epoch 00322: val_loss did not improve from 9.54630
#
# Epoch 00323: val_loss did not improve from 9.54630
#
# Epoch 00324: val_loss did not improve from 9.54630
#
# Epoch 00325: val_loss did not improve from 9.54630
#
# Epoch 00326: val_loss did not improve from 9.54630
#
# Epoch 00327: val_loss did not improve from 9.54630
#
# Epoch 00328: val_loss did not improve from 9.54630
#
# Epoch 00329: val_loss did not improve from 9.54630
#
# Epoch 00330: val_loss did not improve from 9.54630
#
# Epoch 00331: val_loss did not improve from 9.54630
#
# Epoch 00332: val_loss did not improve from 9.54630
#
# Epoch 00333: val_loss did not improve from 9.54630
#
# Epoch 00334: val_loss did not improve from 9.54630
#
# Epoch 00335: val_loss did not improve from 9.54630
#
# Epoch 00336: val_loss did not improve from 9.54630
#
# Epoch 00337: val_loss did not improve from 9.54630
#
# Epoch 00338: val_loss did not improve from 9.54630
#
# Epoch 00339: val_loss did not improve from 9.54630
#
# Epoch 00340: val_loss did not improve from 9.54630
#
# Epoch 00341: val_loss did not improve from 9.54630
#
# Epoch 00342: val_loss did not improve from 9.54630
#
# Epoch 00343: val_loss did not improve from 9.54630
#
# Epoch 00344: val_loss improved from 9.54630 to 9.16864, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00345: val_loss did not improve from 9.16864
#
# Epoch 00346: val_loss improved from 9.16864 to 8.81725, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00347: val_loss did not improve from 8.81725
#
# Epoch 00348: val_loss did not improve from 8.81725
#
# Epoch 00349: val_loss did not improve from 8.81725
#
# Epoch 00350: val_loss did not improve from 8.81725
#
# Epoch 00351: val_loss did not improve from 8.81725
#
# Epoch 00352: val_loss did not improve from 8.81725
#
# Epoch 00353: val_loss did not improve from 8.81725
#
# Epoch 00354: val_loss did not improve from 8.81725
#
# Epoch 00355: val_loss did not improve from 8.81725
#
# Epoch 00356: val_loss did not improve from 8.81725
#
# Epoch 00357: val_loss did not improve from 8.81725
#
# Epoch 00358: val_loss did not improve from 8.81725
#
# Epoch 00359: val_loss did not improve from 8.81725
#
# Epoch 00360: val_loss did not improve from 8.81725
#
# Epoch 00361: val_loss did not improve from 8.81725
#
# Epoch 00362: val_loss did not improve from 8.81725
#
# Epoch 00363: val_loss did not improve from 8.81725
#
# Epoch 00364: val_loss did not improve from 8.81725
#
# Epoch 00365: val_loss improved from 8.81725 to 7.55808, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00366: val_loss did not improve from 7.55808
#
# Epoch 00367: val_loss did not improve from 7.55808
#
# Epoch 00368: val_loss did not improve from 7.55808
#
# Epoch 00369: val_loss did not improve from 7.55808
#
# Epoch 00370: val_loss did not improve from 7.55808
#
# Epoch 00371: val_loss did not improve from 7.55808
#
# Epoch 00372: val_loss did not improve from 7.55808
#
# Epoch 00373: val_loss did not improve from 7.55808
#
# Epoch 00374: val_loss did not improve from 7.55808
#
# Epoch 00375: val_loss did not improve from 7.55808
#
# Epoch 00376: val_loss did not improve from 7.55808
#
# Epoch 00377: val_loss did not improve from 7.55808
#
# Epoch 00378: val_loss did not improve from 7.55808
#
# Epoch 00379: val_loss did not improve from 7.55808
#
# Epoch 00380: val_loss did not improve from 7.55808
#
# Epoch 00381: val_loss did not improve from 7.55808
#
# Epoch 00382: val_loss did not improve from 7.55808
#
# Epoch 00383: val_loss did not improve from 7.55808
#
# Epoch 00384: val_loss did not improve from 7.55808
#
# Epoch 00385: val_loss did not improve from 7.55808
#
# Epoch 00386: val_loss did not improve from 7.55808
# Epoch 00387: val_loss did not improve from 7.55808
#
# Epoch 00388: val_loss did not improve from 7.55808
#
# Epoch 00389: val_loss did not improve from 7.55808
#
# Epoch 00390: val_loss did not improve from 7.55808
#
# Epoch 00391: val_loss did not improve from 7.55808
#
# Epoch 00392: val_loss did not improve from 7.55808
#
# Epoch 00393: val_loss did not improve from 7.55808
#
# Epoch 00394: val_loss did not improve from 7.55808
#
# Epoch 00395: val_loss did not improve from 7.55808
#
# Epoch 00396: val_loss did not improve from 7.55808
#
# Epoch 00397: val_loss did not improve from 7.55808
#
# Epoch 00398: val_loss did not improve from 7.55808
#
# Epoch 00399: val_loss did not improve from 7.55808
#
# Epoch 00400: val_loss did not improve from 7.55808
#
# Epoch 00401: val_loss did not improve from 7.55808
#
# Epoch 00402: val_loss did not improve from 7.55808
#
# Epoch 00403: val_loss did not improve from 7.55808
#
# Epoch 00404: val_loss did not improve from 7.55808
#
# Epoch 00405: val_loss did not improve from 7.55808
#
# Epoch 00406: val_loss did not improve from 7.55808
#
# Epoch 00407: val_loss did not improve from 7.55808
#
# Epoch 00408: val_loss did not improve from 7.55808
#
# Epoch 00409: val_loss did not improve from 7.55808
#
# Epoch 00410: val_loss did not improve from 7.55808
#
# Epoch 00411: val_loss did not improve from 7.55808
#
# Epoch 00412: val_loss did not improve from 7.55808
#
# Epoch 00413: val_loss did not improve from 7.55808
#
# Epoch 00414: val_loss did not improve from 7.55808
#
# Epoch 00415: val_loss did not improve from 7.55808
#
# Epoch 00416: val_loss did not improve from 7.55808
#
# Epoch 00417: val_loss did not improve from 7.55808
#
# Epoch 00418: val_loss did not improve from 7.55808
#
# Epoch 00419: val_loss did not improve from 7.55808
#
# Epoch 00420: val_loss did not improve from 7.55808
#
# Epoch 00421: val_loss did not improve from 7.55808
#
# Epoch 00422: val_loss did not improve from 7.55808
#
# Epoch 00423: val_loss did not improve from 7.55808
#
# Epoch 00424: val_loss did not improve from 7.55808
#
# Epoch 00425: val_loss did not improve from 7.55808
#
# Epoch 00426: val_loss did not improve from 7.55808
#
# Epoch 00427: val_loss did not improve from 7.55808
#
# Epoch 00428: val_loss did not improve from 7.55808
#
# Epoch 00429: val_loss did not improve from 7.55808
#
# Epoch 00430: val_loss did not improve from 7.55808
#
# Epoch 00431: val_loss did not improve from 7.55808
#
# Epoch 00432: val_loss did not improve from 7.55808
#
# Epoch 00433: val_loss did not improve from 7.55808
#
# Epoch 00434: val_loss did not improve from 7.55808
#
# Epoch 00435: val_loss did not improve from 7.55808
#
# Epoch 00436: val_loss did not improve from 7.55808
#
# Epoch 00437: val_loss did not improve from 7.55808
#
# Epoch 00438: val_loss did not improve from 7.55808
#
# Epoch 00439: val_loss did not improve from 7.55808
#
# Epoch 00440: val_loss did not improve from 7.55808
#
# Epoch 00441: val_loss did not improve from 7.55808
#
# Epoch 00442: val_loss did not improve from 7.55808
#
# Epoch 00443: val_loss did not improve from 7.55808
#
# Epoch 00444: val_loss did not improve from 7.55808
#
# Epoch 00445: val_loss did not improve from 7.55808
#
# Epoch 00446: val_loss did not improve from 7.55808
#
# Epoch 00447: val_loss did not improve from 7.55808
#
# Epoch 00448: val_loss did not improve from 7.55808
#
# Epoch 00449: val_loss did not improve from 7.55808
#
# Epoch 00450: val_loss did not improve from 7.55808
#
# Epoch 00451: val_loss did not improve from 7.55808
#
# Epoch 00452: val_loss did not improve from 7.55808
#
# Epoch 00453: val_loss did not improve from 7.55808
#
# Epoch 00454: val_loss did not improve from 7.55808
#
# Epoch 00455: val_loss did not improve from 7.55808
#
# Epoch 00456: val_loss did not improve from 7.55808
#
# Epoch 00457: val_loss did not improve from 7.55808
#
# Epoch 00458: val_loss did not improve from 7.55808
#
# Epoch 00459: val_loss did not improve from 7.55808
#
# Epoch 00460: val_loss did not improve from 7.55808
#
# Epoch 00461: val_loss did not improve from 7.55808
#
# Epoch 00462: val_loss did not improve from 7.55808
#
# Epoch 00463: val_loss did not improve from 7.55808
#
# Epoch 00464: val_loss did not improve from 7.55808
#
# Epoch 00465: val_loss did not improve from 7.55808
#
# Epoch 00466: val_loss did not improve from 7.55808
#
# Epoch 00467: val_loss did not improve from 7.55808
#
# Epoch 00468: val_loss did not improve from 7.55808
#
# Epoch 00469: val_loss did not improve from 7.55808
#
# Epoch 00470: val_loss did not improve from 7.55808
#
# Epoch 00471: val_loss did not improve from 7.55808
#
# Epoch 00472: val_loss did not improve from 7.55808
#
# Epoch 00473: val_loss did not improve from 7.55808
#
# Epoch 00474: val_loss did not improve from 7.55808
#
# Epoch 00475: val_loss did not improve from 7.55808
#
# Epoch 00476: val_loss did not improve from 7.55808
#
# Epoch 00477: val_loss did not improve from 7.55808
#
# Epoch 00478: val_loss did not improve from 7.55808
#
# Epoch 00479: val_loss did not improve from 7.55808
#
# Epoch 00480: val_loss did not improve from 7.55808
#
# Epoch 00481: val_loss did not improve from 7.55808
#
# Epoch 00482: val_loss did not improve from 7.55808
#
# Epoch 00483: val_loss did not improve from 7.55808
#
# Epoch 00484: val_loss did not improve from 7.55808
#
# Epoch 00485: val_loss did not improve from 7.55808
#
# Epoch 00486: val_loss did not improve from 7.55808
#
# Epoch 00487: val_loss did not improve from 7.55808
#
# Epoch 00488: val_loss did not improve from 7.55808
#
# Epoch 00489: val_loss did not improve from 7.55808
#
# Epoch 00490: val_loss did not improve from 7.55808
#
# Epoch 00491: val_loss did not improve from 7.55808
#
# Epoch 00492: val_loss did not improve from 7.55808
#
# Epoch 00493: val_loss did not improve from 7.55808
#
# Epoch 00494: val_loss did not improve from 7.55808
#
# Epoch 00495: val_loss did not improve from 7.55808
#
# Epoch 00496: val_loss did not improve from 7.55808
#
# Epoch 00497: val_loss did not improve from 7.55808
#
# Epoch 00498: val_loss did not improve from 7.55808
#
# Epoch 00499: val_loss did not improve from 7.55808
#
# Epoch 00500: val_loss did not improve from 7.55808
#
# Epoch 00501: val_loss did not improve from 7.55808
#
# Epoch 00502: val_loss did not improve from 7.55808
#
# Epoch 00503: val_loss did not improve from 7.55808
#
# Epoch 00504: val_loss did not improve from 7.55808
#
# Epoch 00505: val_loss did not improve from 7.55808
#
# Epoch 00506: val_loss did not improve from 7.55808
#
# Epoch 00507: val_loss did not improve from 7.55808
#
# Epoch 00508: val_loss did not improve from 7.55808
#
# Epoch 00509: val_loss did not improve from 7.55808
#
# Epoch 00510: val_loss did not improve from 7.55808
#
# Epoch 00511: val_loss did not improve from 7.55808
#
# Epoch 00512: val_loss did not improve from 7.55808
#
# Epoch 00513: val_loss did not improve from 7.55808
#
# Epoch 00514: val_loss did not improve from 7.55808
#
# Epoch 00515: val_loss did not improve from 7.55808
#
# Epoch 00516: val_loss did not improve from 7.55808
#
# Epoch 00517: val_loss did not improve from 7.55808
#
# Epoch 00518: val_loss did not improve from 7.55808
#
# Epoch 00519: val_loss did not improve from 7.55808
#
# Epoch 00520: val_loss did not improve from 7.55808
#
# Epoch 00521: val_loss did not improve from 7.55808
#
# Epoch 00522: val_loss did not improve from 7.55808
#
# Epoch 00523: val_loss did not improve from 7.55808
#
# Epoch 00524: val_loss improved from 7.55808 to 7.45910, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00525: val_loss did not improve from 7.45910
#
# Epoch 00526: val_loss did not improve from 7.45910
#
# Epoch 00527: val_loss did not improve from 7.45910
#
# Epoch 00528: val_loss did not improve from 7.45910
#
# Epoch 00529: val_loss did not improve from 7.45910
#
# Epoch 00530: val_loss did not improve from 7.45910
#
# Epoch 00531: val_loss did not improve from 7.45910
#
# Epoch 00532: val_loss did not improve from 7.45910
#
# Epoch 00533: val_loss did not improve from 7.45910
#
# Epoch 00534: val_loss did not improve from 7.45910
#
# Epoch 00535: val_loss did not improve from 7.45910
#
# Epoch 00536: val_loss did not improve from 7.45910
#
# Epoch 00537: val_loss did not improve from 7.45910
#
# Epoch 00538: val_loss did not improve from 7.45910
#
# Epoch 00539: val_loss did not improve from 7.45910
#
# Epoch 00540: val_loss did not improve from 7.45910
#
# Epoch 00541: val_loss did not improve from 7.45910
#
# Epoch 00542: val_loss did not improve from 7.45910
# Epoch 00543: val_loss did not improve from 7.45910
#
# Epoch 00544: val_loss did not improve from 7.45910
#
# Epoch 00545: val_loss did not improve from 7.45910
#
# Epoch 00546: val_loss improved from 7.45910 to 7.23724, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00547: val_loss did not improve from 7.23724
#
# Epoch 00548: val_loss did not improve from 7.23724
#
# Epoch 00549: val_loss did not improve from 7.23724
#
# Epoch 00550: val_loss did not improve from 7.23724
#
# Epoch 00551: val_loss did not improve from 7.23724
#
# Epoch 00552: val_loss did not improve from 7.23724
#
# Epoch 00553: val_loss did not improve from 7.23724
#
# Epoch 00554: val_loss did not improve from 7.23724
#
# Epoch 00555: val_loss did not improve from 7.23724
#
# Epoch 00556: val_loss did not improve from 7.23724
#
# Epoch 00557: val_loss did not improve from 7.23724
#
# Epoch 00558: val_loss did not improve from 7.23724
#
# Epoch 00559: val_loss did not improve from 7.23724
#
# Epoch 00560: val_loss did not improve from 7.23724
#
# Epoch 00561: val_loss improved from 7.23724 to 7.04632, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00562: val_loss did not improve from 7.04632
#
# Epoch 00563: val_loss did not improve from 7.04632
#
# Epoch 00564: val_loss did not improve from 7.04632
#
# Epoch 00565: val_loss did not improve from 7.04632
#
# Epoch 00566: val_loss did not improve from 7.04632
#
# Epoch 00567: val_loss did not improve from 7.04632
#
# Epoch 00568: val_loss did not improve from 7.04632
#
# Epoch 00569: val_loss did not improve from 7.04632
#
# Epoch 00570: val_loss did not improve from 7.04632
#
# Epoch 00571: val_loss did not improve from 7.04632
#
# Epoch 00572: val_loss did not improve from 7.04632
#
# Epoch 00573: val_loss did not improve from 7.04632
#
# Epoch 00574: val_loss did not improve from 7.04632
#
# Epoch 00575: val_loss did not improve from 7.04632
#
# Epoch 00576: val_loss did not improve from 7.04632
#
# Epoch 00577: val_loss did not improve from 7.04632
#
# Epoch 00578: val_loss did not improve from 7.04632
#
# Epoch 00579: val_loss did not improve from 7.04632
#
# Epoch 00580: val_loss did not improve from 7.04632
#
# Epoch 00581: val_loss did not improve from 7.04632
#
# Epoch 00582: val_loss did not improve from 7.04632
#
# Epoch 00583: val_loss did not improve from 7.04632
#
# Epoch 00584: val_loss did not improve from 7.04632
#
# Epoch 00585: val_loss did not improve from 7.04632
#
# Epoch 00586: val_loss did not improve from 7.04632
#
# Epoch 00587: val_loss did not improve from 7.04632
#
# Epoch 00588: val_loss did not improve from 7.04632
#
# Epoch 00589: val_loss did not improve from 7.04632
#
# Epoch 00590: val_loss did not improve from 7.04632
#
# Epoch 00591: val_loss did not improve from 7.04632
#
# Epoch 00592: val_loss did not improve from 7.04632
#
# Epoch 00593: val_loss did not improve from 7.04632
#
# Epoch 00594: val_loss did not improve from 7.04632
#
# Epoch 00595: val_loss did not improve from 7.04632
#
# Epoch 00596: val_loss did not improve from 7.04632
#
# Epoch 00597: val_loss did not improve from 7.04632
#
# Epoch 00598: val_loss did not improve from 7.04632
#
# Epoch 00599: val_loss did not improve from 7.04632
#
# Epoch 00600: val_loss did not improve from 7.04632
#
# Epoch 00601: val_loss did not improve from 7.04632
#
# Epoch 00602: val_loss did not improve from 7.04632
#
# Epoch 00603: val_loss did not improve from 7.04632
#
# Epoch 00604: val_loss did not improve from 7.04632
#
# Epoch 00605: val_loss did not improve from 7.04632
#
# Epoch 00606: val_loss did not improve from 7.04632
#
# Epoch 00607: val_loss did not improve from 7.04632
#
# Epoch 00608: val_loss did not improve from 7.04632
#
# Epoch 00609: val_loss did not improve from 7.04632
#
# Epoch 00610: val_loss did not improve from 7.04632
#
# Epoch 00611: val_loss did not improve from 7.04632
#
# Epoch 00612: val_loss did not improve from 7.04632
#
# Epoch 00613: val_loss did not improve from 7.04632
#
# Epoch 00614: val_loss did not improve from 7.04632
#
# Epoch 00615: val_loss did not improve from 7.04632
#
# Epoch 00616: val_loss did not improve from 7.04632
#
# Epoch 00617: val_loss did not improve from 7.04632
#
# Epoch 00618: val_loss did not improve from 7.04632
#
# Epoch 00619: val_loss did not improve from 7.04632
#
# Epoch 00620: val_loss did not improve from 7.04632
#
# Epoch 00621: val_loss did not improve from 7.04632
#
# Epoch 00622: val_loss did not improve from 7.04632
#
# Epoch 00623: val_loss improved from 7.04632 to 6.82513, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00624: val_loss did not improve from 6.82513
#
# Epoch 00625: val_loss did not improve from 6.82513
#
# Epoch 00626: val_loss did not improve from 6.82513
#
# Epoch 00627: val_loss did not improve from 6.82513
#
# Epoch 00628: val_loss did not improve from 6.82513
#
# Epoch 00629: val_loss did not improve from 6.82513
#
# Epoch 00630: val_loss did not improve from 6.82513
#
# Epoch 00631: val_loss did not improve from 6.82513
#
# Epoch 00632: val_loss did not improve from 6.82513
#
# Epoch 00633: val_loss did not improve from 6.82513
#
# Epoch 00634: val_loss did not improve from 6.82513
#
# Epoch 00635: val_loss did not improve from 6.82513
#
# Epoch 00636: val_loss did not improve from 6.82513
#
# Epoch 00637: val_loss did not improve from 6.82513
#
# Epoch 00638: val_loss did not improve from 6.82513
#
# Epoch 00639: val_loss did not improve from 6.82513
#
# Epoch 00640: val_loss did not improve from 6.82513
#
# Epoch 00641: val_loss did not improve from 6.82513
#
# Epoch 00642: val_loss did not improve from 6.82513
#
# Epoch 00643: val_loss did not improve from 6.82513
#
# Epoch 00644: val_loss did not improve from 6.82513
#
# Epoch 00645: val_loss did not improve from 6.82513
#
# Epoch 00646: val_loss did not improve from 6.82513
#
# Epoch 00647: val_loss did not improve from 6.82513
#
# Epoch 00648: val_loss did not improve from 6.82513
#
# Epoch 00649: val_loss did not improve from 6.82513
#
# Epoch 00650: val_loss did not improve from 6.82513
#
# Epoch 00651: val_loss did not improve from 6.82513
#
# Epoch 00652: val_loss did not improve from 6.82513
#
# Epoch 00653: val_loss did not improve from 6.82513
#
# Epoch 00654: val_loss did not improve from 6.82513
#
# Epoch 00655: val_loss did not improve from 6.82513
#
# Epoch 00656: val_loss did not improve from 6.82513
#
# Epoch 00657: val_loss did not improve from 6.82513
#
# Epoch 00658: val_loss improved from 6.82513 to 6.38581, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00659: val_loss did not improve from 6.38581
#
# Epoch 00660: val_loss did not improve from 6.38581
#
# Epoch 00661: val_loss did not improve from 6.38581
#
# Epoch 00662: val_loss did not improve from 6.38581
#
# Epoch 00663: val_loss did not improve from 6.38581
#
# Epoch 00664: val_loss did not improve from 6.38581
#
# Epoch 00665: val_loss did not improve from 6.38581
#
# Epoch 00666: val_loss did not improve from 6.38581
#
# Epoch 00667: val_loss improved from 6.38581 to 5.85498, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00668: val_loss did not improve from 5.85498
#
# Epoch 00669: val_loss did not improve from 5.85498
#
# Epoch 00670: val_loss did not improve from 5.85498
#
# Epoch 00671: val_loss did not improve from 5.85498
#
# Epoch 00672: val_loss did not improve from 5.85498
#
# Epoch 00673: val_loss did not improve from 5.85498
#
# Epoch 00674: val_loss did not improve from 5.85498
#
# Epoch 00675: val_loss did not improve from 5.85498
#
# Epoch 00676: val_loss did not improve from 5.85498
#
# Epoch 00677: val_loss did not improve from 5.85498
#
# Epoch 00678: val_loss did not improve from 5.85498
#
# Epoch 00679: val_loss did not improve from 5.85498
#
# Epoch 00680: val_loss did not improve from 5.85498
#
# Epoch 00681: val_loss did not improve from 5.85498
#
# Epoch 00682: val_loss did not improve from 5.85498
#
# Epoch 00683: val_loss did not improve from 5.85498
#
# Epoch 00684: val_loss did not improve from 5.85498
#
# Epoch 00685: val_loss did not improve from 5.85498
#
# Epoch 00686: val_loss improved from 5.85498 to 5.04216, saving model to C:/Users/Asus/Desktop/Turbofan-1 LSTM 17/Model checkpoint\1_50_17_ckpt
#
# Epoch 00687: val_loss did not improve from 5.04216
#
# Epoch 00688: val_loss did not improve from 5.04216
#
# Epoch 00689: val_loss did not improve from 5.04216
# Epoch 00690: val_loss did not improve from 5.04216
#
# Epoch 00691: val_loss did not improve from 5.04216
#
# Epoch 00692: val_loss did not improve from 5.04216
#
# Epoch 00693: val_loss did not improve from 5.04216
#
# Epoch 00694: val_loss did not improve from 5.04216
#
# Epoch 00695: val_loss did not improve from 5.04216
#
# Epoch 00696: val_loss did not improve from 5.04216
#
# Epoch 00697: val_loss did not improve from 5.04216
#
# Epoch 00698: val_loss did not improve from 5.04216
#
# Epoch 00699: val_loss did not improve from 5.04216
#
# Epoch 00700: val_loss did not improve from 5.04216
#
# Epoch 00701: val_loss did not improve from 5.04216
#
# Epoch 00702: val_loss did not improve from 5.04216
#
# Epoch 00703: val_loss did not improve from 5.04216
#
# Epoch 00704: val_loss did not improve from 5.04216
#
# Epoch 00705: val_loss did not improve from 5.04216
#
# Epoch 00706: val_loss did not improve from 5.04216
#
# Epoch 00707: val_loss did not improve from 5.04216
#
# Epoch 00708: val_loss did not improve from 5.04216
#
# Epoch 00709: val_loss did not improve from 5.04216
#
# Epoch 00710: val_loss did not improve from 5.04216
#
# Epoch 00711: val_loss did not improve from 5.04216
#
# Epoch 00712: val_loss did not improve from 5.04216
#
# Epoch 00713: val_loss did not improve from 5.04216
#
# Epoch 00714: val_loss did not improve from 5.04216
#
# Epoch 00715: val_loss did not improve from 5.04216
#
# Epoch 00716: val_loss did not improve from 5.04216
#
# Epoch 00717: val_loss did not improve from 5.04216
#
# Epoch 00718: val_loss did not improve from 5.04216
#
# Epoch 00719: val_loss did not improve from 5.04216
#
# Epoch 00720: val_loss did not improve from 5.04216
#
# Epoch 00721: val_loss did not improve from 5.04216
#
# Epoch 00722: val_loss did not improve from 5.04216
#
# Epoch 00723: val_loss did not improve from 5.04216
#
# Epoch 00724: val_loss did not improve from 5.04216
#
# Epoch 00725: val_loss did not improve from 5.04216
#
# Epoch 00726: val_loss did not improve from 5.04216
#
# Epoch 00727: val_loss did not improve from 5.04216
#
# Epoch 00728: val_loss did not improve from 5.04216
#
# Epoch 00729: val_loss did not improve from 5.04216
#
# Epoch 00730: val_loss did not improve from 5.04216
#
# Epoch 00731: val_loss did not improve from 5.04216
#
# Epoch 00732: val_loss did not improve from 5.04216
#
# Epoch 00733: val_loss did not improve from 5.04216
#
# Epoch 00734: val_loss did not improve from 5.04216
#
# Epoch 00735: val_loss did not improve from 5.04216
#
# Epoch 00736: val_loss did not improve from 5.04216
#
# Epoch 00737: val_loss did not improve from 5.04216
#
# Epoch 00738: val_loss did not improve from 5.04216
#
# Epoch 00739: val_loss did not improve from 5.04216
#
# Epoch 00740: val_loss did not improve from 5.04216
#
# Epoch 00741: val_loss did not improve from 5.04216
#
# Epoch 00742: val_loss did not improve from 5.04216
#
# Epoch 00743: val_loss did not improve from 5.04216
#
# Epoch 00744: val_loss did not improve from 5.04216
#
# Epoch 00745: val_loss did not improve from 5.04216
#
# Epoch 00746: val_loss did not improve from 5.04216
#
# Epoch 00747: val_loss did not improve from 5.04216
#
# Epoch 00748: val_loss did not improve from 5.04216
#
# Epoch 00749: val_loss did not improve from 5.04216
#
# Epoch 00750: val_loss did not improve from 5.04216
#
# Epoch 00751: val_loss did not improve from 5.04216
#
# Epoch 00752: val_loss did not improve from 5.04216
#
# Epoch 00753: val_loss did not improve from 5.04216
#
# Epoch 00754: val_loss did not improve from 5.04216
#
# Epoch 00755: val_loss did not improve from 5.04216
#
# Epoch 00756: val_loss did not improve from 5.04216
#
# Epoch 00757: val_loss did not improve from 5.04216
#
# Epoch 00758: val_loss did not improve from 5.04216
#
# Epoch 00759: val_loss did not improve from 5.04216
#
# Epoch 00760: val_loss did not improve from 5.04216
#
# Epoch 00761: val_loss did not improve from 5.04216
#
# Epoch 00762: val_loss did not improve from 5.04216
#
# Epoch 00763: val_loss did not improve from 5.04216
#
# Epoch 00764: val_loss did not improve from 5.04216
#
# Epoch 00765: val_loss did not improve from 5.04216
#
# Epoch 00766: val_loss did not improve from 5.04216
#
# Epoch 00767: val_loss did not improve from 5.04216
#
# Epoch 00768: val_loss did not improve from 5.04216
#
# Epoch 00769: val_loss did not improve from 5.04216
#
# Epoch 00770: val_loss did not improve from 5.04216
#
# Epoch 00771: val_loss did not improve from 5.04216
#
# Epoch 00772: val_loss did not improve from 5.04216
#
# Epoch 00773: val_loss did not improve from 5.04216
#
# Epoch 00774: val_loss did not improve from 5.04216
#
# Epoch 00775: val_loss did not improve from 5.04216
#
# Epoch 00776: val_loss did not improve from 5.04216
#
# Epoch 00777: val_loss did not improve from 5.04216
#
# Epoch 00778: val_loss did not improve from 5.04216
#
# Epoch 00779: val_loss did not improve from 5.04216
#
# Epoch 00780: val_loss did not improve from 5.04216
#
# Epoch 00781: val_loss did not improve from 5.04216
#
# Epoch 00782: val_loss did not improve from 5.04216
#
# Epoch 00783: val_loss did not improve from 5.04216
#
# Epoch 00784: val_loss did not improve from 5.04216
#
# Epoch 00785: val_loss did not improve from 5.04216
#
# Epoch 00786: val_loss did not improve from 5.04216
#
# Epoch 00787: val_loss did not improve from 5.04216
#
# Epoch 00788: val_loss did not improve from 5.04216
#
# Epoch 00789: val_loss did not improve from 5.04216
#
# Epoch 00790: val_loss did not improve from 5.04216
#
# Epoch 00791: val_loss did not improve from 5.04216
#
# Epoch 00792: val_loss did not improve from 5.04216
#
# Epoch 00793: val_loss did not improve from 5.04216
#
# Epoch 00794: val_loss did not improve from 5.04216
#
# Epoch 00795: val_loss did not improve from 5.04216
#
# Epoch 00796: val_loss did not improve from 5.04216
#
# Epoch 00797: val_loss did not improve from 5.04216
#
# Epoch 00798: val_loss did not improve from 5.04216
#
# Epoch 00799: val_loss did not improve from 5.04216
#
# Epoch 00800: val_loss did not improve from 5.04216
#
# Epoch 00801: val_loss did not improve from 5.04216
#
# Epoch 00802: val_loss did not improve from 5.04216
#
# Epoch 00803: val_loss did not improve from 5.04216
#
# Epoch 00804: val_loss did not improve from 5.04216
#
# Epoch 00805: val_loss did not improve from 5.04216
#
# Epoch 00806: val_loss did not improve from 5.04216
#
# Epoch 00807: val_loss did not improve from 5.04216
#
# Epoch 00808: val_loss did not improve from 5.04216
#
# Epoch 00809: val_loss did not improve from 5.04216
#
# Epoch 00810: val_loss did not improve from 5.04216
#
# Epoch 00811: val_loss did not improve from 5.04216
#
# Epoch 00812: val_loss did not improve from 5.04216
#
# Epoch 00813: val_loss did not improve from 5.04216
#
# Epoch 00814: val_loss did not improve from 5.04216
#
# Epoch 00815: val_loss did not improve from 5.04216
#
# Epoch 00816: val_loss did not improve from 5.04216
#
# Epoch 00817: val_loss did not improve from 5.04216
#
# Epoch 00818: val_loss did not improve from 5.04216
#
# Epoch 00819: val_loss did not improve from 5.04216
#
# Epoch 00820: val_loss did not improve from 5.04216
#
# Epoch 00821: val_loss did not improve from 5.04216
#
# Epoch 00822: val_loss did not improve from 5.04216
#
# ...
#
# Epoch 09694: val_loss did not improve from 0.50076
#
# Epoch 09695: val_loss did not improve from 0.50076
#
# Epoch 09696: val_loss did not improve from 0.50076
#
# Epoch 09697: val_loss did not improve from 0.50076
#
# Epoch 09698: val_loss did not improve from 0.50076
#
# Epoch 09699: val_loss did not improve from 0.50076
#
# Epoch 09700: val_loss did not improve from 0.50076
#
# Epoch 09701: val_loss did not improve from 0.50076
#
# Epoch 09702: val_loss did not improve from 0.50076
#
# Epoch 09703: val_loss did not improve from 0.50076
#
# Epoch 09704: val_loss did not improve from 0.50076
#
# Epoch 09705: val_loss did not improve from 0.50076
#
# Epoch 09706: val_loss did not improve from 0.50076
#
# Epoch 09707: val_loss did not improve from 0.50076
#
# Epoch 09708: val_loss did not improve from 0.50076
#
# Epoch 09709: val_loss did not improve from 0.50076
#
# Epoch 09710: val_loss did not improve from 0.50076
#
# Epoch 09711: val_loss did not improve from 0.50076
#
# Epoch 09712: val_loss did not improve from 0.50076
#
# Epoch 09713: val_loss did not improve from 0.50076
#
# Epoch 09714: val_loss did not improve from 0.50076
#
# Epoch 09715: val_loss did not improve from 0.50076
#
# Epoch 09716: val_loss did not improve from 0.50076
#
# Epoch 09717: val_loss did not improve from 0.50076
#
# Epoch 09718: val_loss did not improve from 0.50076
#
# Epoch 09719: val_loss did not improve from 0.50076
#
# Epoch 09720: val_loss did not improve from 0.50076
#
# Epoch 09721: val_loss did not improve from 0.50076
#
# Epoch 09722: val_loss did not improve from 0.50076
#
# Epoch 09723: val_loss did not improve from 0.50076
#
# Epoch 09724: val_loss did not improve from 0.50076
#
# Epoch 09725: val_loss did not improve from 0.50076
#
# Epoch 09726: val_loss did not improve from 0.50076
#
# Epoch 09727: val_loss did not improve from 0.50076
#
# Epoch 09728: val_loss did not improve from 0.50076
#
# Epoch 09729: val_loss did not improve from 0.50076
#
# Epoch 09730: val_loss did not improve from 0.50076
#
# Epoch 09731: val_loss did not improve from 0.50076
#
# Epoch 09732: val_loss did not improve from 0.50076
#
# Epoch 09733: val_loss did not improve from 0.50076
#
# Epoch 09734: val_loss did not improve from 0.50076
#
# Epoch 09735: val_loss did not improve from 0.50076
#
# Epoch 09736: val_loss did not improve from 0.50076
#
# Epoch 09737: val_loss did not improve from 0.50076
#
# Epoch 09738: val_loss did not improve from 0.50076
#
# Epoch 09739: val_loss did not improve from 0.50076
#
# Epoch 09740: val_loss did not improve from 0.50076
#
# Epoch 09741: val_loss did not improve from 0.50076
#
# Epoch 09742: val_loss did not improve from 0.50076
#
# Epoch 09743: val_loss did not improve from 0.50076
#
# Epoch 09744: val_loss did not improve from 0.50076
#
# Epoch 09745: val_loss did not improve from 0.50076
#
# Epoch 09746: val_loss did not improve from 0.50076
#
# Epoch 09747: val_loss did not improve from 0.50076
#
# Epoch 09748: val_loss did not improve from 0.50076
#
# Epoch 09749: val_loss did not improve from 0.50076
#
# Epoch 09750: val_loss did not improve from 0.50076
#
# Epoch 09751: val_loss did not improve from 0.50076
#
# Epoch 09752: val_loss did not improve from 0.50076
#
# Epoch 09753: val_loss did not improve from 0.50076
#
# Epoch 09754: val_loss did not improve from 0.50076
#
# Epoch 09755: val_loss did not improve from 0.50076
#
# Epoch 09756: val_loss did not improve from 0.50076
#
# Epoch 09757: val_loss did not improve from 0.50076
#
# Epoch 09758: val_loss did not improve from 0.50076
#
# Epoch 09759: val_loss did not improve from 0.50076
#
# Epoch 09760: val_loss did not improve from 0.50076
#
# Epoch 09761: val_loss did not improve from 0.50076
#
# Epoch 09762: val_loss did not improve from 0.50076
#
# Epoch 09763: val_loss did not improve from 0.50076
#
# Epoch 09764: val_loss did not improve from 0.50076
#
# Epoch 09765: val_loss did not improve from 0.50076
#
# Epoch 09766: val_loss did not improve from 0.50076
#
# Epoch 09767: val_loss did not improve from 0.50076
#
# Epoch 09768: val_loss did not improve from 0.50076
#
# Epoch 09769: val_loss did not improve from 0.50076
#
# Epoch 09770: val_loss did not improve from 0.50076
#
# Epoch 09771: val_loss did not improve from 0.50076
#
# Epoch 09772: val_loss did not improve from 0.50076
#
# Epoch 09773: val_loss did not improve from 0.50076
#
# Epoch 09774: val_loss did not improve from 0.50076
#
# Epoch 09775: val_loss did not improve from 0.50076
#
# Epoch 09776: val_loss did not improve from 0.50076
#
# Epoch 09777: val_loss did not improve from 0.50076
#
# Epoch 09778: val_loss did not improve from 0.50076
#
# Epoch 09779: val_loss did not improve from 0.50076
#
# Epoch 09780: val_loss did not improve from 0.50076
#
# Epoch 09781: val_loss did not improve from 0.50076
#
# Epoch 09782: val_loss did not improve from 0.50076
#
# Epoch 09783: val_loss did not improve from 0.50076
#
# Epoch 09784: val_loss did not improve from 0.50076
#
# Epoch 09785: val_loss did not improve from 0.50076
#
# Epoch 09786: val_loss did not improve from 0.50076
#
# Epoch 09787: val_loss did not improve from 0.50076
#
# Epoch 09788: val_loss did not improve from 0.50076
#
# Epoch 09789: val_loss did not improve from 0.50076
#
# Epoch 09790: val_loss did not improve from 0.50076
#
# Epoch 09791: val_loss did not improve from 0.50076
#
# Epoch 09792: val_loss did not improve from 0.50076
#
# Epoch 09793: val_loss did not improve from 0.50076
#
# Epoch 09794: val_loss did not improve from 0.50076
#
# Epoch 09795: val_loss did not improve from 0.50076
#
# Epoch 09796: val_loss did not improve from 0.50076
#
# Epoch 09797: val_loss did not improve from 0.50076
#
# Epoch 09798: val_loss did not improve from 0.50076
#
# Epoch 09799: val_loss did not improve from 0.50076
#
# Epoch 09800: val_loss did not improve from 0.50076
#
# Epoch 09801: val_loss did not improve from 0.50076
#
# Epoch 09802: val_loss did not improve from 0.50076
#
# Epoch 09803: val_loss did not improve from 0.50076
#
# Epoch 09804: val_loss did not improve from 0.50076
#
# Epoch 09805: val_loss did not improve from 0.50076
#
# Epoch 09806: val_loss did not improve from 0.50076
#
# Epoch 09807: val_loss did not improve from 0.50076
#
# Epoch 09808: val_loss did not improve from 0.50076
#
# Epoch 09809: val_loss did not improve from 0.50076
#
# Epoch 09810: val_loss did not improve from 0.50076
#
# Epoch 09811: val_loss did not improve from 0.50076
#
# Epoch 09812: val_loss did not improve from 0.50076
#
# Epoch 09813: val_loss did not improve from 0.50076
#
# Epoch 09814: val_loss did not improve from 0.50076
#
# Epoch 09815: val_loss did not improve from 0.50076
#
# Epoch 09816: val_loss did not improve from 0.50076
#
# Epoch 09817: val_loss did not improve from 0.50076
#
# Epoch 09818: val_loss did not improve from 0.50076
#
# Epoch 09819: val_loss did not improve from 0.50076
#
# Epoch 09820: val_loss did not improve from 0.50076
#
# Epoch 09821: val_loss did not improve from 0.50076
#
# Epoch 09822: val_loss did not improve from 0.50076
#
# Epoch 09823: val_loss did not improve from 0.50076
#
# Epoch 09824: val_loss did not improve from 0.50076
#
# Epoch 09825: val_loss did not improve from 0.50076
#
# Epoch 09826: val_loss did not improve from 0.50076
#
# Epoch 09827: val_loss did not improve from 0.50076
#
# Epoch 09828: val_loss did not improve from 0.50076
#
# Epoch 09829: val_loss did not improve from 0.50076
#
# Epoch 09830: val_loss did not improve from 0.50076
#
# Epoch 09831: val_loss did not improve from 0.50076
#
# Epoch 09832: val_loss did not improve from 0.50076
# Epoch 09833: val_loss did not improve from 0.50076
#
# Epoch 09834: val_loss did not improve from 0.50076
#
# Epoch 09835: val_loss did not improve from 0.50076
#
# Epoch 09836: val_loss did not improve from 0.50076
#
# Epoch 09837: val_loss did not improve from 0.50076
#
# Epoch 09838: val_loss did not improve from 0.50076
#
# Epoch 09839: val_loss did not improve from 0.50076
#
# Epoch 09840: val_loss did not improve from 0.50076
#
# Epoch 09841: val_loss did not improve from 0.50076
#
# Epoch 09842: val_loss did not improve from 0.50076
#
# Epoch 09843: val_loss did not improve from 0.50076
#
# Epoch 09844: val_loss did not improve from 0.50076
#
# Epoch 09845: val_loss did not improve from 0.50076
#
# Epoch 09846: val_loss did not improve from 0.50076
#
# Epoch 09847: val_loss did not improve from 0.50076
#
# Epoch 09848: val_loss did not improve from 0.50076
#
# Epoch 09849: val_loss did not improve from 0.50076
#
# Epoch 09850: val_loss did not improve from 0.50076
#
# Epoch 09851: val_loss did not improve from 0.50076
#
# Epoch 09852: val_loss did not improve from 0.50076
#
# Epoch 09853: val_loss did not improve from 0.50076
#
# Epoch 09854: val_loss did not improve from 0.50076
#
# Epoch 09855: val_loss did not improve from 0.50076
#
# Epoch 09856: val_loss did not improve from 0.50076
#
# Epoch 09857: val_loss did not improve from 0.50076
#
# Epoch 09858: val_loss did not improve from 0.50076
#
# Epoch 09859: val_loss did not improve from 0.50076
#
# Epoch 09860: val_loss did not improve from 0.50076
#
# Epoch 09861: val_loss did not improve from 0.50076
#
# Epoch 09862: val_loss did not improve from 0.50076
#
# Epoch 09863: val_loss did not improve from 0.50076
#
# Epoch 09864: val_loss did not improve from 0.50076
#
# Epoch 09865: val_loss did not improve from 0.50076
#
# Epoch 09866: val_loss did not improve from 0.50076
#
# Epoch 09867: val_loss did not improve from 0.50076
#
# Epoch 09868: val_loss did not improve from 0.50076
#
# Epoch 09869: val_loss did not improve from 0.50076
#
# Epoch 09870: val_loss did not improve from 0.50076
#
# Epoch 09871: val_loss did not improve from 0.50076
#
# Epoch 09872: val_loss did not improve from 0.50076
#
# Epoch 09873: val_loss did not improve from 0.50076
#
# Epoch 09874: val_loss did not improve from 0.50076
#
# Epoch 09875: val_loss did not improve from 0.50076
#
# Epoch 09876: val_loss did not improve from 0.50076
#
# Epoch 09877: val_loss did not improve from 0.50076
#
# Epoch 09878: val_loss did not improve from 0.50076
#
# Epoch 09879: val_loss did not improve from 0.50076
#
# Epoch 09880: val_loss did not improve from 0.50076
#
# Epoch 09881: val_loss did not improve from 0.50076
#
# Epoch 09882: val_loss did not improve from 0.50076
#
# Epoch 09883: val_loss did not improve from 0.50076
#
# Epoch 09884: val_loss did not improve from 0.50076
#
# Epoch 09885: val_loss did not improve from 0.50076
#
# Epoch 09886: val_loss did not improve from 0.50076
#
# Epoch 09887: val_loss did not improve from 0.50076
#
# Epoch 09888: val_loss did not improve from 0.50076
#
# Epoch 09889: val_loss did not improve from 0.50076
#
# Epoch 09890: val_loss did not improve from 0.50076
#
# Epoch 09891: val_loss did not improve from 0.50076
#
# Epoch 09892: val_loss did not improve from 0.50076
#
# Epoch 09893: val_loss did not improve from 0.50076
#
# Epoch 09894: val_loss did not improve from 0.50076
#
# Epoch 09895: val_loss did not improve from 0.50076
#
# Epoch 09896: val_loss did not improve from 0.50076
#
# Epoch 09897: val_loss did not improve from 0.50076
#
# Epoch 09898: val_loss did not improve from 0.50076
#
# Epoch 09899: val_loss did not improve from 0.50076
#
# Epoch 09900: val_loss did not improve from 0.50076
#
# Epoch 09901: val_loss did not improve from 0.50076
#
# Epoch 09902: val_loss did not improve from 0.50076
#
# Epoch 09903: val_loss did not improve from 0.50076
#
# Epoch 09904: val_loss did not improve from 0.50076
#
# Epoch 09905: val_loss did not improve from 0.50076
#
# Epoch 09906: val_loss did not improve from 0.50076
#
# Epoch 09907: val_loss did not improve from 0.50076
#
# Epoch 09908: val_loss did not improve from 0.50076
#
# Epoch 09909: val_loss did not improve from 0.50076
#
# Epoch 09910: val_loss did not improve from 0.50076
#
# Epoch 09911: val_loss did not improve from 0.50076
#
# Epoch 09912: val_loss did not improve from 0.50076
#
# Epoch 09913: val_loss did not improve from 0.50076
#
# Epoch 09914: val_loss did not improve from 0.50076
#
# Epoch 09915: val_loss did not improve from 0.50076
#
# Epoch 09916: val_loss did not improve from 0.50076
#
# Epoch 09917: val_loss did not improve from 0.50076
#
# Epoch 09918: val_loss did not improve from 0.50076
#
# Epoch 09919: val_loss did not improve from 0.50076
#
# Epoch 09920: val_loss did not improve from 0.50076
#
# Epoch 09921: val_loss did not improve from 0.50076
#
# Epoch 09922: val_loss did not improve from 0.50076
#
# Epoch 09923: val_loss did not improve from 0.50076
#
# Epoch 09924: val_loss did not improve from 0.50076
#
# Epoch 09925: val_loss did not improve from 0.50076
#
# Epoch 09926: val_loss did not improve from 0.50076
#
# Epoch 09927: val_loss did not improve from 0.50076
#
# Epoch 09928: val_loss did not improve from 0.50076
#
# Epoch 09929: val_loss did not improve from 0.50076
#
# Epoch 09930: val_loss did not improve from 0.50076
#
# Epoch 09931: val_loss did not improve from 0.50076
#
# Epoch 09932: val_loss did not improve from 0.50076
#
# Epoch 09933: val_loss did not improve from 0.50076
#
# Epoch 09934: val_loss did not improve from 0.50076
#
# Epoch 09935: val_loss did not improve from 0.50076
#
# Epoch 09936: val_loss did not improve from 0.50076
#
# Epoch 09937: val_loss did not improve from 0.50076
#
# Epoch 09938: val_loss did not improve from 0.50076
#
# Epoch 09939: val_loss did not improve from 0.50076
#
# Epoch 09940: val_loss did not improve from 0.50076
#
# Epoch 09941: val_loss did not improve from 0.50076
#
# Epoch 09942: val_loss did not improve from 0.50076
#
# Epoch 09943: val_loss did not improve from 0.50076
#
# Epoch 09944: val_loss did not improve from 0.50076
#
# Epoch 09945: val_loss did not improve from 0.50076
#
# Epoch 09946: val_loss did not improve from 0.50076
#
# Epoch 09947: val_loss did not improve from 0.50076
#
# Epoch 09948: val_loss did not improve from 0.50076
#
# Epoch 09949: val_loss did not improve from 0.50076
#
# Epoch 09950: val_loss did not improve from 0.50076
#
# Epoch 09951: val_loss did not improve from 0.50076
#
# Epoch 09952: val_loss did not improve from 0.50076
#
# Epoch 09953: val_loss did not improve from 0.50076
#
# Epoch 09954: val_loss did not improve from 0.50076
#
# Epoch 09955: val_loss did not improve from 0.50076
#
# Epoch 09956: val_loss did not improve from 0.50076
#
# Epoch 09957: val_loss did not improve from 0.50076
#
# Epoch 09958: val_loss did not improve from 0.50076
#
# Epoch 09959: val_loss did not improve from 0.50076
#
# Epoch 09960: val_loss did not improve from 0.50076
#
# Epoch 09961: val_loss did not improve from 0.50076
#
# Epoch 09962: val_loss did not improve from 0.50076
#
# Epoch 09963: val_loss did not improve from 0.50076
#
# Epoch 09964: val_loss did not improve from 0.50076
#
# Epoch 09965: val_loss did not improve from 0.50076
#
# Epoch 09966: val_loss did not improve from 0.50076
#
# Epoch 09967: val_loss did not improve from 0.50076
#
# Epoch 09968: val_loss did not improve from 0.50076
#
# Epoch 09969: val_loss did not improve from 0.50076
#
# Epoch 09970: val_loss did not improve from 0.50076
#
# Epoch 09971: val_loss did not improve from 0.50076
#
# Epoch 09972: val_loss did not improve from 0.50076
#
# Epoch 09973: val_loss did not improve from 0.50076
#
# Epoch 09974: val_loss did not improve from 0.50076
#
# Epoch 09975: val_loss did not improve from 0.50076
#
# Epoch 09976: val_loss did not improve from 0.50076
#
# Epoch 09977: val_loss did not improve from 0.50076
#
# Epoch 09978: val_loss did not improve from 0.50076
#
# Epoch 09979: val_loss did not improve from 0.50076
#
# Epoch 09980: val_loss did not improve from 0.50076
#
# Epoch 09981: val_loss did not improve from 0.50076
#
# Epoch 09982: val_loss did not improve from 0.50076
#
# Epoch 09983: val_loss did not improve from 0.50076
#
# Epoch 09984: val_loss did not improve from 0.50076
#
# Epoch 09985: val_loss did not improve from 0.50076
#
# Epoch 09986: val_loss did not improve from 0.50076
#
# Epoch 09987: val_loss did not improve from 0.50076
#
# Epoch 09988: val_loss did not improve from 0.50076
#
# Epoch 09989: val_loss did not improve from 0.50076
#
# Epoch 09990: val_loss did not improve from 0.50076
# Epoch 09991: val_loss did not improve from 0.50076
#
# Epoch 09992: val_loss did not improve from 0.50076
#
# Epoch 09993: val_loss did not improve from 0.50076
#
# Epoch 09994: val_loss did not improve from 0.50076
#
# Epoch 09995: val_loss did not improve from 0.50076
#
# Epoch 09996: val_loss did not improve from 0.50076
#
# Epoch 09997: val_loss did not improve from 0.50076
#
# Epoch 09998: val_loss did not improve from 0.50076
#
# Epoch 09999: val_loss did not improve from 0.50076
#
# Epoch 10000: val_loss did not improve from 0.50076

# %%
#Load best weights into model

import os
os.listdir(checkpoint_dir)
model.load_weights(checkpoint_path)

# %%
#visualize graph

# %tensorboard --logdir logs
#if issue delete log in C:\Users\Asus\AppData\Local\Temp\.tensor_board
# Out:
#       <iframe id="tensorboard-frame-2d529ecb99434f3b" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-2d529ecb99434f3b");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
#moving average smoothing function for loss visualization

def moving_average(x, w):
    return np.convolve(x, np.ones(w), 'valid') / w

# %%
#Plot model loss

w = 1000
h1 = np.array(history.history['loss'])
h4 = np.array(history.history['val_loss'])
h1 = moving_average(h1,w)
h4 = moving_average(h4,w)
plt.plot(h1,label='Train loss')
plt.plot(h4,label='Val loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(bbox_to_anchor=(1.05, 1),loc='best')
plt.show()

# %%
#Plot output 1 loss

h2 = np.array(history.history['out1_loss'])
h5 = np.array(history.history['val_out1_loss'])
h2 = moving_average(h2,w)
h5 = moving_average(h5,w)
plt.plot(h2,label='layer out 1 Train loss')
plt.plot(h5,label='layer out 1 Val loss')
plt.title('Output 1 Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(bbox_to_anchor=(1.05, 1),loc='best')
plt.show()

# %%
#Plot output 2 loss

h3 = np.array(history.history['out2_loss'])
h6 = np.array(history.history['val_out2_loss'])
h3 = moving_average(h3,w)
h6 = moving_average(h6,w)
plt.plot(h3,label='layer out 2 Train loss')
plt.plot(h6,label='layer out 2 Val loss')
plt.title('Output 2 Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(bbox_to_anchor=(1.05, 1),loc='best')
plt.show()

# %%
#Load ground truth RUL

thr = mat['thr']
fleet_NUM = np.arange(0,pad,1)

rul = pd.read_csv(rul_file,index_col=False)
rul = (rul-1)/(thr-1)
rul_Fleet_All = np.zeros(100)
for x in range(100):
    rul_Fleet_All[x] = rul['RUL'][x]
rul_Fleet_All_Full = ((thr-1)*rul_Fleet_All) + 1
rul_Fleet_All_Full
# Out:
# array([50., 50., 50., 50., 50., 50., 50., 50., 50., 50., 50., 50., 50.,
#        50., 50., 50., 50., 28., 50., 16., 50., 50., 50., 20., 50., 50.,
#        50., 50., 50., 50.,  8., 48., 50.,  7., 11., 19., 21., 50., 50.,
#        28., 18., 10., 50., 50., 50., 47., 50., 50., 21., 50., 50., 29.,
#        26., 50., 50., 15., 50., 37., 50., 50., 21., 50., 50., 28., 50.,
#        14., 50.,  8., 50., 50., 50., 50., 50., 50., 50., 10., 34., 50.,
#        50., 50.,  8.,  9., 50., 50., 50., 50., 50., 50., 50., 28., 38.,
#        20., 50., 50., 50., 50., 50., 50., 50., 20.])

# %%
#Make 100 predictions and calculate average RMSE & Score

import sklearn
import math
from sklearn import metrics

rmse = np.zeros(100)
rmse1 = np.zeros(100)
sc = np.zeros(100)
sc1 = np.zeros(100)

for i in range(100):
    
    preds = model(x_test)
    tens_draw = preds[0].sample(1000)
    tens_draw1 = preds[1].sample(1000)
    tens_draw = tf.keras.backend.get_value(tens_draw)
    tens_draw1 = tf.keras.backend.get_value(tens_draw1)

    #RMSE with AU

    mean_Fleet_All = np.zeros(tens_draw.shape[1])
    mean_Fleet = np.zeros(tens_draw.shape[0])
    for y in range(tens_draw.shape[1]):
        for x in range(tens_draw.shape[0]):
            mean_Fleet[x] = tens_draw[x,y,0]
        mean_Fleet_All[y] = mean_Fleet.mean()

    RUL_mse = sklearn.metrics.mean_squared_error(rul_Fleet_All_Full, mean_Fleet_All)
    RUL_rmse = math.sqrt(RUL_mse)
    rmse[i] = RUL_rmse

    #RMSE with EU

    mean_Fleet_All1 = np.zeros(tens_draw1.shape[1])
    mean_Fleet1 = np.zeros(tens_draw1.shape[0])
    for y in range(tens_draw1.shape[1]):
        for x in range(tens_draw1.shape[0]):
            mean_Fleet1[x] = tens_draw1[x,y,0]
        mean_Fleet_All1[y] = mean_Fleet1.mean()

    RUL_mse1 = sklearn.metrics.mean_squared_error(rul_Fleet_All_Full, mean_Fleet_All1)
    RUL_rmse1 = math.sqrt(RUL_mse1)
    rmse1[i] = RUL_rmse1
    
    score = mean_Fleet_All-rul_Fleet_All_Full

    for j in range(100):
        if score[j]<0:
            score[j]= math.exp((-score[j])/13)-1
        else:
            score[j] = math.exp(score[j]/10)-1
    
    sc[i] = np.sum(score)
    
    score1 = mean_Fleet_All1-rul_Fleet_All_Full

    for j in range(100):
        if score1[j]<0:
            score1[j]= math.exp((-score1[j])/13)-1
        else:
            score1[j] = math.exp(score1[j]/10)-1
    
    sc1[i] = np.sum(score1)

# %%
#Average RMSE with AU & EU
np.mean(rmse),np.mean(rmse1)
# Out:
# (17.878835287710068, 18.285125180804158)

# %%
#Average early prediction Score with AU & EU
np.mean(sc),np.mean(sc1)
# Out:
# (1000.8854707845345, 1145.0542964920255)

# %%
#Calculate Mean & Std of prediction with AU

Fleet = pd.DataFrame(np.zeros((pad,tens_draw.shape[0])))
mean = pd.DataFrame(np.zeros((pad,1)))
std = pd.DataFrame(np.zeros((pad,1)))
for y in range(tens_draw1.shape[0]):
    Fleet[y] = tens_draw[y][0]
    row_Mean = Fleet.mean(axis=1)
    row_Std = Fleet.std(axis=1)
    for j in range(pad):
        mean[0][j] = row_Mean[j]
    for k in range(pad):
        std[0][k] = row_Std[k]

# %%
#Calculate Mean & Std of prediction with EU

Fleet1 = pd.DataFrame(np.zeros((pad,tens_draw1.shape[0])))
mean1 = pd.DataFrame(np.zeros((pad,1)))
std1 = pd.DataFrame(np.zeros((pad,1)))
for y in range(tens_draw1.shape[0]):
    Fleet1[y] = tens_draw1[y][0]
    row_Mean = Fleet1.mean(axis=1)
    row_Std = Fleet1.std(axis=1)
    for j in range(pad):
        mean1[0][j] = row_Mean[j]
    for k in range(pad):
        std1[0][k] = row_Std[k]

# %%
#Load ground truth RUL

fleet_RUL = pd.read_csv(fleet_Rul_File, skiprows = 0,header = None)

# %%
max_RUL_Arrange = pd.DataFrame(np.zeros((100,2)))
for x in range(100):
    max_RUL_Arrange[0][x] = fleet_NUM[x]
    max_RUL_Arrange[1][x] = ((thr-1)*fleet_RUL[0][x]) + 1
max_RUL_Arrange.columns = ['Cycle','RUL']

# %%
#3d visualization of prediction
# %matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
from scipy import stats
from scipy.stats import norm

sns.set_style('ticks')

# %matplotlib inline
plt.figure(figsize=(15,8))
ax = plt.axes(projection='3d')
ax.set_xlim3d(-10, 100)
ax.set_ylim3d(-20, 65)
ax.set_zlim3d(0, 0.6)

ax.xaxis.pane.fill = False
ax.yaxis.pane.fill = False
ax.zaxis.pane.fill = False

ax.set_xlabel('Cycle',fontsize='14')
ax.set_ylabel('RUL',fontsize='14')
ax.set_zlabel('Density',fontsize='14')

ax.xaxis.pane.set_edgecolor('w')
ax.yaxis.pane.set_edgecolor('w')
ax.zaxis.pane.set_edgecolor('w')


s = np.arange(0,100,1)

i = 0
Fleetx = Fleet.iloc[i:i+1,:].to_numpy().reshape(1000,)
mindist = Fleetx.min()
maxdist = Fleetx.max()
y = np.linspace(mindist,maxdist,1000)
#ax.scatter3D(np.full((1000,),i),Fleetx,0,color = 'black',marker=".",alpha=0.01,label = "Prediction")
ax.plot3D(np.full((1000,),i),y,stats.norm.pdf(y,mean[0][i]),color = 'darkblue', label = "Prediction Distribution", alpha=0.5)

i = 12
Fleetx = Fleet.iloc[i:i+1,:].to_numpy().reshape(1000,)
mindist = Fleetx.min()
maxdist = Fleetx.max()
y = np.linspace(mindist,maxdist,1000)
#ax.scatter3D(np.full((1000,),i),Fleetx,0,color = 'black',marker=".",alpha=0.01)
ax.plot3D(np.full((1000,),i),y,stats.norm.pdf(y,mean[0][i]),color = 'darkblue', alpha=0.5)

i = 35
Fleetx = Fleet.iloc[i:i+1,:].to_numpy().reshape(1000,)
mindist = Fleetx.min()
maxdist = Fleetx.max()
y = np.linspace(mindist,maxdist,1000)
#ax.scatter3D(np.full((1000,),i),Fleetx,0,color = 'black',marker=".",alpha=0.01)
ax.plot3D(np.full((1000,),i),y,stats.norm.pdf(y,mean[0][i],std[0][i]),color = 'darkblue',alpha=0.5)

i = 65
Fleetx = Fleet.iloc[i:i+1,:].to_numpy().reshape(1000,)
mindist = Fleetx.min()
maxdist = Fleetx.max()
y = np.linspace(mindist,maxdist,1000)
#ax.scatter3D(np.full((1000,),i),Fleetx,0,color = 'black',marker=".",alpha=0.01)
ax.plot3D(np.full((1000,),i),y,stats.norm.pdf(y,mean[0][i],std[0][i]),color = 'darkblue',alpha=0.5)

i = 85
Fleetx = Fleet.iloc[i:i+1,:].to_numpy().reshape(1000,)
mindist = Fleetx.min()
maxdist = Fleetx.max()
y = np.linspace(mindist,maxdist,1000)
#ax.scatter3D(np.full((1000,),i),Fleetx,0,color = 'black',marker=".",alpha=0.01)
ax.plot3D(np.full((1000,),i),y,stats.norm.pdf(y,mean[0][i],std[0][i]),color = 'darkblue',alpha=0.5)

ax.scatter3D(s,mean[0][0:100],linewidth=0.03,marker="o",color = "darkblue", alpha=0.7,label='Prediction Mean')
ax.plot3D(s,max_RUL_Arrange['RUL'],linewidth=2,marker="_",markersize=1,color = 'r',label='True RUL')

ax.text(-3.5, 46, 0.42, "Cycle 0", color='darkorange')
ax.text(9, 45, 0.42, "Cycle 13", color='darkorange')
ax.text(31, 25, 0.30, "Cycle 36", color='darkorange')
ax.text(60, 0, 0.60, "Cycle 66", color='darkorange')
ax.text(80, 0, 0.575, "Cycle 86", color='darkorange')

plt.legend(bbox_to_anchor=(1.05,1),loc='upper left')
#ax.view_init(0, 45)
plt.show()
# Out:
# Using matplotlib backend: Qt5Agg

# %%
sns.set_style('ticks')

# %matplotlib inline
plt.figure(figsize=(15,8))
ax = plt.axes(projection='3d')
ax.set_xlim3d(-10, 100)
ax.set_ylim3d(-20, 65)
ax.set_zlim3d(0, 0.6)

ax.xaxis.pane.fill = False
ax.yaxis.pane.fill = False
ax.zaxis.pane.fill = False

ax.set_xlabel('Cycle',fontsize='14')
ax.set_ylabel('RUL',fontsize='14')
ax.set_zlabel('Density',fontsize='14')

ax.xaxis.pane.set_edgecolor('w')
ax.yaxis.pane.set_edgecolor('w')
ax.zaxis.pane.set_edgecolor('w')

s = np.arange(0,100,1)

i = 0
Fleetx = Fleet1.iloc[i:i+1,:].to_numpy().reshape(1000,)
mindist = Fleetx.min()
maxdist = Fleetx.max()
y = np.linspace(mindist,maxdist,1000)
#ax.plot3D(np.full((1000,),i),Fleetx,0,color = 'coral',marker=".",markersize=0.35,label='Prediction')
ax.plot3D(np.full((1000,),i),y,stats.norm.pdf(y,mean1[0][i],std1[0][i]),color = 'slateblue', alpha=0.5, label="Prediction Distribution")

i = 12
Fleetx = Fleet1.iloc[i:i+1,:].to_numpy().reshape(1000,)
mindist = Fleetx.min()
maxdist = Fleetx.max()
y = np.linspace(mindist,maxdist,1000)
#ax.plot3D(np.full((1000,),i),Fleetx,0,color = 'coral',marker=".",markersize=0.35)
ax.plot3D(np.full((1000,),i),y,stats.norm.pdf(y,mean1[0][i],std1[0][i]),color = 'slateblue', alpha=0.5)

i = 35
Fleetx = Fleet1.iloc[i:i+1,:].to_numpy().reshape(1000,)
mindist = Fleetx.min()
maxdist = Fleetx.max()
y = np.linspace(mindist,maxdist,1000)
#ax.plot3D(np.full((1000,),i),Fleetx,0,color = 'coral',marker=".",markersize=0.35)
ax.plot3D(np.full((1000,),i),y,stats.norm.pdf(y,mean1[0][i],std1[0][i]),color = 'slateblue', alpha=0.5)

i = 65
Fleetx = Fleet1.iloc[i:i+1,:].to_numpy().reshape(1000,)
mindist = Fleetx.min()
maxdist = Fleetx.max()
y = np.linspace(mindist,maxdist,1000)
#ax.plot3D(np.full((1000,),i),Fleetx,0,color = 'coral',marker=".",markersize=0.35)
ax.plot3D(np.full((1000,),i),y,stats.norm.pdf(y,mean1[0][i],std1[0][i]),color = 'slateblue', alpha=0.5)

i = 85
Fleetx = Fleet1.iloc[i:i+1,:].to_numpy().reshape(1000,)
mindist = Fleetx.min()
maxdist = Fleetx.max()
y = np.linspace(mindist,maxdist,1000)
#ax.plot3D(np.full((1000,),i),Fleetx,0,color = 'coral',marker=".",markersize=0.35)
ax.plot3D(np.full((1000,),i),y,stats.norm.pdf(y,mean1[0][i],std1[0][i]),color = 'slateblue', alpha=0.5)

ax.scatter3D(s,mean1[0][0:100],linewidth=0.03,marker="o",color = 'slateblue',alpha=1,label='Prediction Mean')
ax.plot3D(s,max_RUL_Arrange['RUL'],linewidth=2,marker="_",markersize=1,color = 'r',label='True RUL')

ax.text(-1, 46, 0.425, "Cycle 0", color='darkorange')
ax.text(11, 45, 0.435, "Cycle 13", color='darkorange')
ax.text(33, 25, 0.43, "Cycle 36", color='darkorange')
ax.text(60, 0, 0.41, "Cycle 66", color='darkorange')
ax.text(79.5, 0, 0.41, "Cycle 86", color='darkorange')

plt.legend(bbox_to_anchor=(1.05,1),loc='upper left')
plt.show()

# %%
#Define cycle when RUL ground truth become 0

cycle_lim = np.zeros(100)
S = 0
for K in range(100):
    for L in range(pad):
        if fleet_RUL[K][L] == 0:
            S = 0
            break
        else:
            S = S + 1
            cycle_lim[K] = S

# %%
#Visualization Fleet 1

import seaborn as sns
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes 
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
from scipy import stats
sns.set()
for B in range(0,1):
    lim = 100#int(cycle_lim[B]+1)
    lim2 = 100#int(cycle_lim[B]+1)
    max_Seq = pd.DataFrame(np.zeros((lim,tens_draw.shape[0])))
    for y in range(tens_draw.shape[0]):
        for x in range(lim):
            max_Seq[y][x] = tens_draw[y,B,x]

    max_Seq_Arrange = pd.DataFrame(np.zeros((lim*tens_draw.shape[0],2)))
    z = 0
    m = 0
    s = 0
    while s < lim*tens_draw.shape[0]:
        if(m < (tens_draw.shape[0])):
            max_Seq_Arrange[0][s] = fleet_NUM[z]
            max_Seq_Arrange[1][s] = max_Seq[m][z]
            m = m + 1
            s = s + 1
        else:
            #print("change")
            z = z + 1
            m = 0
        continue
    
    max_Seq1 = pd.DataFrame(np.zeros((lim,tens_draw1.shape[0])))
    for y in range(tens_draw1.shape[0]):
        for x in range(lim):
            max_Seq1[y][x] = tens_draw1[y,B,x]

    max_Seq_Arrange1 = pd.DataFrame(np.zeros((lim*tens_draw1.shape[0],2)))
    z = 0
    m = 0
    s = 0
    while s < lim*tens_draw1.shape[0]:
        if(m < (tens_draw1.shape[0])):
            max_Seq_Arrange1[0][s] = fleet_NUM[z]
            max_Seq_Arrange1[1][s] = max_Seq1[m][z]
            m = m + 1
            s = s + 1
        else:
            #print("change")
            z = z + 1
            m = 0
        continue

    max_Seq_Arrange.columns = ['Cycle','RUL']
    max_RUL_Arrange = pd.DataFrame(np.zeros((lim2,2)))
    for x in range(lim2):
        max_RUL_Arrange[0][x] = fleet_NUM[x]
        max_RUL_Arrange[1][x] = ((thr-1)*fleet_RUL[B][x]) + 1
    max_RUL_Arrange.columns = ['Cycle','RUL']
    
    max_Seq_Arrange1.columns = ['Cycle','RUL']

    min_Std_Arrange = pd.DataFrame(np.zeros((lim,2)))
    for x in range(lim):
        min_Std_Arrange[0][x] = fleet_NUM[x]
        min_Std_Arrange[1][x] = std[0][x]
    min_Std_Arrange.columns = ['Cycle','RUL']
    
    med_Std_Arrange = pd.DataFrame(np.zeros((lim,2)))
    for x in range(lim):
        med_Std_Arrange[0][x] = fleet_NUM[x]
        med_Std_Arrange[1][x] = std1[0][x]
    med_Std_Arrange.columns = ['Cycle','RUL']
    
    #get coeffs of linear fit
    slope, intercept, r_value, p_value, std_err = stats.linregress(min_Std_Arrange['Cycle'],min_Std_Arrange['RUL'])
    gs = gridspec.GridSpec(3,1)
    fig = plt.figure(figsize=(10,10))

    ax = fig.add_subplot(gs[0])
    sns.lineplot(x="Cycle", y="RUL",ci = "sd", marker='o', data=max_Seq_Arrange, color='darkblue',ax=ax, label="RUL Prediction with AU")
    sns.lineplot(x="Cycle", y="RUL",ci = "sd", marker='o', data=max_Seq_Arrange1, color='slateblue',ax=ax, label="RUL Prediction with EU")
    sns.lineplot(x="Cycle", y="RUL", data = max_RUL_Arrange, color='r', ax=ax,label="True RUL")
    plt.title('Turbofan-%i Prognostic with Uncertainty Using 17 Features' %(B+1),fontsize=14)
    ax.set_xlabel('Cycle')
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

    ax = fig.add_subplot(gs[1],sharex=ax)
    ax.plot('Cycle', 'RUL', data=min_Std_Arrange,linestyle= '-', color = '#101820FF',linewidth=0.7, label='Standard Deviation')
    sns.regplot(min_Std_Arrange['Cycle'],min_Std_Arrange['RUL'],scatter = False,label='Slope')
    plt.title('Turbofan-%i AU Rolling Standard Deviation' %(B+1),fontsize=14)
    ax.set_xlabel('Cycle')
    ax.set_ylabel('Standard Deviation')
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    
    ax = fig.add_subplot(gs[2],sharex=ax)
    ax.plot('Cycle', 'RUL', data=med_Std_Arrange,linestyle= '-', color = '#101820FF',linewidth=0.7, label='Standard Deviation')
    sns.regplot(med_Std_Arrange['Cycle'],med_Std_Arrange['RUL'],scatter = False,label='Slope')
    plt.title('Turbofan-%i EU Rolling Standard Deviation' %(B+1),fontsize=14)
    ax.set_xlabel('Cycle')
    ax.set_ylabel('Standard Deviation')
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.savefig("Fleet %i Pred" %B+'.jpg')
    plt.tight_layout()
    plt.show()

# %%
#Visualization Fleet 1

import seaborn as sns
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes 
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
from scipy import stats
sns.set()
for B in range(0,1):
    lim = 100#int(cycle_lim[B]+1)
    lim2 = 100#int(cycle_lim[B]+1)
    max_Seq = pd.DataFrame(np.zeros((lim,tens_draw.shape[0])))
    for y in range(tens_draw.shape[0]):
        for x in range(lim):
            max_Seq[y][x] = tens_draw[y,B,x]

    max_Seq_Arrange = pd.DataFrame(np.zeros((lim*tens_draw.shape[0],2)))
    z = 0
    m = 0
    s = 0
    while s < lim*tens_draw.shape[0]:
        if(m < (tens_draw.shape[0])):
            max_Seq_Arrange[0][s] = fleet_NUM[z]
            max_Seq_Arrange[1][s] = max_Seq[m][z]
            m = m + 1
            s = s + 1
        else:
            #print("change")
            z = z + 1
            m = 0
        continue
    
    max_Seq1 = pd.DataFrame(np.zeros((lim,tens_draw1.shape[0])))
    for y in range(tens_draw1.shape[0]):
        for x in range(lim):
            max_Seq1[y][x] = tens_draw1[y,B,x]

    max_Seq_Arrange1 = pd.DataFrame(np.zeros((lim*tens_draw1.shape[0],2)))
    z = 0
    m = 0
    s = 0
    while s < lim*tens_draw1.shape[0]:
        if(m < (tens_draw1.shape[0])):
            max_Seq_Arrange1[0][s] = fleet_NUM[z]
            max_Seq_Arrange1[1][s] = max_Seq1[m][z]
            m = m + 1
            s = s + 1
        else:
            #print("change")
            z = z + 1
            m = 0
        continue

    max_Seq_Arrange.columns = ['Cycle','RUL']
    max_RUL_Arrange = pd.DataFrame(np.zeros((lim2,2)))
    for x in range(lim2):
        max_RUL_Arrange[0][x] = fleet_NUM[x]
        max_RUL_Arrange[1][x] = ((thr-1)*fleet_RUL[B][x]) + 1
    max_RUL_Arrange.columns = ['Cycle','RUL']
    
    max_Seq_Arrange1.columns = ['Cycle','RUL']

    min_Std_Arrange = pd.DataFrame(np.zeros((lim,2)))
    for x in range(lim):
        min_Std_Arrange[0][x] = fleet_NUM[x]
        min_Std_Arrange[1][x] = std[0][x]
    min_Std_Arrange.columns = ['Cycle','RUL']
    
    med_Std_Arrange = pd.DataFrame(np.zeros((lim,2)))
    for x in range(lim):
        med_Std_Arrange[0][x] = fleet_NUM[x]
        med_Std_Arrange[1][x] = std1[0][x]
    med_Std_Arrange.columns = ['Cycle','RUL']
    
    #get coeffs of linear fit
    slope, intercept, r_value, p_value, std_err = stats.linregress(min_Std_Arrange['Cycle'],min_Std_Arrange['RUL'])
    gs = gridspec.GridSpec(3,1)
    fig = plt.figure(figsize=(10,10))

    ax = fig.add_subplot(gs[0])
    sns.lineplot(x="Cycle", y="RUL",ci = "sd", marker='o', data=max_Seq_Arrange, color='darkblue',ax=ax, label="RUL Prediction with AU")
    sns.lineplot(x="Cycle", y="RUL",ci = "sd", marker='o', data=max_Seq_Arrange1, color='slateblue',ax=ax, label="RUL Prediction with EU")
    sns.lineplot(x="Cycle", y="RUL", data = max_RUL_Arrange, color='r', ax=ax,label="True RUL")
    #plt.title('Turbofan-%i Prognostic with Uncertainty Using 17 Features' %(B+1),fontsize=14)
    ax.set_xlabel('Cycle')
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

    ax = fig.add_subplot(gs[1],sharex=ax)
    ax.plot('Cycle', 'RUL', data=min_Std_Arrange,linestyle= '-', color = '#101820FF',linewidth=0.7, label='Standard Deviation')
    sns.regplot(min_Std_Arrange['Cycle'],min_Std_Arrange['RUL'],scatter = False,label='Slope')
    #plt.title('Turbofan-%i AU Rolling Standard Deviation' %(B+1),fontsize=14)
    ax.set_xlabel('Cycle')
    ax.set_ylabel('Standard Deviation')
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    
    ax = fig.add_subplot(gs[2],sharex=ax)
    ax.plot('Cycle', 'RUL', data=med_Std_Arrange,linestyle= '-', color = '#101820FF',linewidth=0.7, label='Standard Deviation')
    sns.regplot(med_Std_Arrange['Cycle'],med_Std_Arrange['RUL'],scatter = False,label='Slope')
    #plt.title('Turbofan-%i EU Rolling Standard Deviation' %(B+1),fontsize=14)
    ax.set_xlabel('Cycle')
    ax.set_ylabel('Standard Deviation')
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.savefig("Fleet %i Pred" %B+'.jpg')
    plt.tight_layout()
    plt.show()

# %%
#Calculate Mean & Std of prediction Turbofan 18 with AU

Fleet3 = pd.DataFrame(np.zeros((pad,tens_draw.shape[0])))
mean3 = pd.DataFrame(np.zeros((pad,tens_draw.shape[1])))
std3 = pd.DataFrame(np.zeros((pad,tens_draw.shape[1])))
for y in range(1000):
    Fleet3[y] = tens_draw[y][17]
    row_Mean = Fleet3.mean(axis=1)
    row_Std = Fleet3.std(axis=1)
    for j in range(pad):
        mean3[0][j] = row_Mean[j]
    for k in range(pad):
        std3[0][k] = row_Std[k]

# %%
#Calculate Mean & Std of prediction Turbofan 18 with EU

Fleet4 = pd.DataFrame(np.zeros((pad,tens_draw1.shape[0])))
mean4 = pd.DataFrame(np.zeros((pad,tens_draw1.shape[1])))
std4 = pd.DataFrame(np.zeros((pad,tens_draw1.shape[1])))
for y in range(tens_draw1.shape[0]):
    Fleet4[y] = tens_draw1[y][17]
    row_Mean = Fleet4.mean(axis=1)
    row_Std = Fleet4.std(axis=1)
    for j in range(pad):
        mean4[0][j] = row_Mean[j]
    for k in range(pad):
        std4[0][k] = row_Std[k]

# %%
#Visualization Fleet 18

sns.set()
for B in range(17,18):
    lim = 80#int(cycle_lim[B]+1)
    lim2 = 80#int(cycle_lim[B]+1)
    max_Seq = pd.DataFrame(np.zeros((lim,tens_draw.shape[0])))
    for y in range(tens_draw.shape[0]):
        for x in range(lim):
            max_Seq[y][x] = tens_draw[y,B,x]

    max_Seq_Arrange = pd.DataFrame(np.zeros((lim*tens_draw.shape[0],2)))
    z = 0
    m = 0
    s = 0
    while s < lim*tens_draw.shape[0]:
        if(m < (tens_draw.shape[0])):
            max_Seq_Arrange[0][s] = fleet_NUM[z]
            max_Seq_Arrange[1][s] = max_Seq[m][z]
            m = m + 1
            s = s + 1
        else:
            z = z + 1
            m = 0
        continue
    
    max_Seq1 = pd.DataFrame(np.zeros((lim,tens_draw1.shape[0])))
    for y in range(tens_draw1.shape[0]):
        for x in range(lim):
            max_Seq1[y][x] = tens_draw1[y,B,x]

    max_Seq_Arrange1 = pd.DataFrame(np.zeros((lim*tens_draw1.shape[0],2)))
    z = 0
    m = 0
    s = 0
    while s < lim*tens_draw1.shape[0]:
        if(m < (tens_draw1.shape[0])):
            max_Seq_Arrange1[0][s] = fleet_NUM[z]
            max_Seq_Arrange1[1][s] = max_Seq1[m][z]
            m = m + 1
            s = s + 1
        else:
            z = z + 1
            m = 0
        continue

    max_Seq_Arrange.columns = ['Cycle','RUL']
    max_RUL_Arrange = pd.DataFrame(np.zeros((lim2,2)))
    for x in range(lim2):
        max_RUL_Arrange[0][x] = fleet_NUM[x]
        max_RUL_Arrange[1][x] = ((thr-1)*fleet_RUL[B][x]) + 1
    max_RUL_Arrange.columns = ['Cycle','RUL']
    
    max_Seq_Arrange1.columns = ['Cycle','RUL']

    min_Std_Arrange = pd.DataFrame(np.zeros((lim,2)))
    for x in range(lim):
        min_Std_Arrange[0][x] = fleet_NUM[x]
        min_Std_Arrange[1][x] = std3[0][x]
    min_Std_Arrange.columns = ['Cycle','RUL']
    
    med_Std_Arrange = pd.DataFrame(np.zeros((lim,2)))
    for x in range(lim):
        med_Std_Arrange[0][x] = fleet_NUM[x]
        med_Std_Arrange[1][x] = std4[0][x]
    med_Std_Arrange.columns = ['Cycle','RUL']
    
    #get coeffs of linear fit
    slope, intercept, r_value, p_value, std_err = stats.linregress(min_Std_Arrange['Cycle'],min_Std_Arrange['RUL'])
    gs = gridspec.GridSpec(3,1)
    fig = plt.figure(figsize=(10,10))

    ax = fig.add_subplot(gs[0])
    sns.lineplot(x="Cycle", y="RUL",ci = "sd", marker='o', data=max_Seq_Arrange, color='darkblue',ax=ax, label="RUL Prediction with AU")
    sns.lineplot(x="Cycle", y="RUL",ci = "sd", marker='o', data=max_Seq_Arrange1, color='slateblue',ax=ax, label="RUL Prediction with EU")
    sns.lineplot(x="Cycle", y="RUL", data = max_RUL_Arrange, color='r', ax=ax,label="True RUL")
    plt.title('Turbofan-%i Prognostic with Uncertainty Using 17 Features' %(B+1),fontsize=14)
    ax.set_xlabel('Cycle')
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

    ax = fig.add_subplot(gs[1],sharex=ax)
    ax.plot('Cycle', 'RUL', data=min_Std_Arrange,linestyle= '-', color = '#101820FF',linewidth=0.7, label='Standard Deviation')
    sns.regplot(min_Std_Arrange['Cycle'],min_Std_Arrange['RUL'],scatter = False,label='Slope')
    plt.title('Turbofan-%i AU Rolling Standard Deviation' %(B+1),fontsize=14)
    ax.set_xlabel('Cycle')
    ax.set_ylabel('Standard Deviation')
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    
    ax = fig.add_subplot(gs[2],sharex=ax)
    ax.plot('Cycle', 'RUL', data=med_Std_Arrange,linestyle= '-', color = '#101820FF',linewidth=0.7, label='Standard Deviation')
    sns.regplot(med_Std_Arrange['Cycle'],med_Std_Arrange['RUL'],scatter = False,label='Slope')
    plt.title('Turbofan-%i EU Rolling Standard Deviation' %(B+1),fontsize=14)
    ax.set_xlabel('Cycle')
    ax.set_ylabel('Standard Deviation')
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.tight_layout()
    plt.show()

# %%
#Visualization Fleet 18

sns.set()
for B in range(17,18):
    lim = 80#int(cycle_lim[B]+1)
    lim2 = 80#int(cycle_lim[B]+1)
    max_Seq = pd.DataFrame(np.zeros((lim,tens_draw.shape[0])))
    for y in range(tens_draw.shape[0]):
        for x in range(lim):
            max_Seq[y][x] = tens_draw[y,B,x]

    max_Seq_Arrange = pd.DataFrame(np.zeros((lim*tens_draw.shape[0],2)))
    z = 0
    m = 0
    s = 0
    while s < lim*tens_draw.shape[0]:
        if(m < (tens_draw.shape[0])):
            max_Seq_Arrange[0][s] = fleet_NUM[z]
            max_Seq_Arrange[1][s] = max_Seq[m][z]
            m = m + 1
            s = s + 1
        else:
            z = z + 1
            m = 0
        continue
    
    max_Seq1 = pd.DataFrame(np.zeros((lim,tens_draw1.shape[0])))
    for y in range(tens_draw1.shape[0]):
        for x in range(lim):
            max_Seq1[y][x] = tens_draw1[y,B,x]

    max_Seq_Arrange1 = pd.DataFrame(np.zeros((lim*tens_draw1.shape[0],2)))
    z = 0
    m = 0
    s = 0
    while s < lim*tens_draw1.shape[0]:
        if(m < (tens_draw1.shape[0])):
            max_Seq_Arrange1[0][s] = fleet_NUM[z]
            max_Seq_Arrange1[1][s] = max_Seq1[m][z]
            m = m + 1
            s = s + 1
        else:
            z = z + 1
            m = 0
        continue

    max_Seq_Arrange.columns = ['Cycle','RUL']
    max_RUL_Arrange = pd.DataFrame(np.zeros((lim2,2)))
    for x in range(lim2):
        max_RUL_Arrange[0][x] = fleet_NUM[x]
        max_RUL_Arrange[1][x] = ((thr-1)*fleet_RUL[B][x]) + 1
    max_RUL_Arrange.columns = ['Cycle','RUL']
    
    max_Seq_Arrange1.columns = ['Cycle','RUL']

    min_Std_Arrange = pd.DataFrame(np.zeros((lim,2)))
    for x in range(lim):
        min_Std_Arrange[0][x] = fleet_NUM[x]
        min_Std_Arrange[1][x] = std3[0][x]
    min_Std_Arrange.columns = ['Cycle','RUL']
    
    med_Std_Arrange = pd.DataFrame(np.zeros((lim,2)))
    for x in range(lim):
        med_Std_Arrange[0][x] = fleet_NUM[x]
        med_Std_Arrange[1][x] = std4[0][x]
    med_Std_Arrange.columns = ['Cycle','RUL']
    
    #get coeffs of linear fit
    slope, intercept, r_value, p_value, std_err = stats.linregress(min_Std_Arrange['Cycle'],min_Std_Arrange['RUL'])
    gs = gridspec.GridSpec(3,1)
    fig = plt.figure(figsize=(10,10))

    ax = fig.add_subplot(gs[0])
    sns.lineplot(x="Cycle", y="RUL",ci = "sd", marker='o', data=max_Seq_Arrange, color='darkblue',ax=ax, label="RUL Prediction with AU")
    sns.lineplot(x="Cycle", y="RUL",ci = "sd", marker='o', data=max_Seq_Arrange1, color='slateblue',ax=ax, label="RUL Prediction with EU")
    sns.lineplot(x="Cycle", y="RUL", data = max_RUL_Arrange, color='r', ax=ax,label="True RUL")
    #plt.title('Turbofan-%i Prognostic with Uncertainty Using 17 Features' %(B+1),fontsize=14)
    ax.set_xlabel('Cycle')
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

    ax = fig.add_subplot(gs[1],sharex=ax)
    ax.plot('Cycle', 'RUL', data=min_Std_Arrange,linestyle= '-', color = '#101820FF',linewidth=0.7, label='Standard Deviation')
    sns.regplot(min_Std_Arrange['Cycle'],min_Std_Arrange['RUL'],scatter = False,label='Slope')
    #plt.title('Turbofan-%i AU Rolling Standard Deviation' %(B+1),fontsize=14)
    ax.set_xlabel('Cycle')
    ax.set_ylabel('Standard Deviation')
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    
    ax = fig.add_subplot(gs[2],sharex=ax)
    ax.plot('Cycle', 'RUL', data=med_Std_Arrange,linestyle= '-', color = '#101820FF',linewidth=0.7, label='Standard Deviation')
    sns.regplot(med_Std_Arrange['Cycle'],med_Std_Arrange['RUL'],scatter = False,label='Slope')
    #plt.title('Turbofan-%i EU Rolling Standard Deviation' %(B+1),fontsize=14)
    ax.set_xlabel('Cycle')
    ax.set_ylabel('Standard Deviation')
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.tight_layout()

# %%
#SHAP cannot be used with model with probabilistic layers. So, transfer learned weights of probabilistic LSTM to a new LSTM without probabilistic layers
#Define New LSTM without probabilistic layers for explanation

inputs = tf.keras.Input(shape=(303,17),dtype='float32')
layer1 = LSTM(unit1,return_sequences = True)(inputs)
layer2 = Dense(size1)(layer1)
layer3 = Dense(1)(layer2)
layer4 = Lambda(lambda t: t[:,-1],name='out2')(layer3)
model2 = tf.keras.Model(inputs=inputs, outputs=layer4)
model2.summary()
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 303, 17)]         0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 303, 64)           20992
# _________________________________________________________________
# dense_2 (Dense)              (None, 303, 364)          23660
# _________________________________________________________________
# dense_3 (Dense)              (None, 303, 1)            365
# _________________________________________________________________
# out2 (Lambda)                (None, 1)                 0
# =================================================================
# Total params: 45,017
# Trainable params: 45,017
# Non-trainable params: 0
# _________________________________________________________________

# %%
a = model.layers[3].get_weights()

b = np.zeros((len(a[0]),1))
for x in range(len(a[0])):
    b[x] = a[0][x][0]
    
d = np.zeros(1)
for x in range(1):
    d[x] = a[1][x]
    
c = [b,d]

# %%
#Transfer weights from old LSTM to new LSTM

model2.layers[0].set_weights(model.layers[0].get_weights())
model2.layers[1].set_weights(model.layers[1].get_weights())
model2.layers[2].set_weights(model.layers[2].get_weights())
model2.layers[3].set_weights(c)

# %%
#Prediction with new LSTM

preds2 = model2(x_test)
y3 = preds2
y3 = tf.keras.backend.get_value(y3)
tens_draw3 = y3

# %%
#Import SHAP & initialized JS

import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
#Extract Feature Names

features = pd.read_csv(train_file, index_col=False)
features = features.drop(['Fleet','Cycle','RUL'],axis=1)
features = np.array(list(features.columns))
features
# Out:
# array(['OC1', 'OC2', 'OC3', 'S2', 'S3', 'S4', 'S7', 'S8', 'S9', 'S11',
#        'S12', 'S13', 'S14', 'S15', 'S17', 'S20', 'S21'], dtype='<U3')

# %%
#load Training Files into Pandas Dataframes for SHAP Plots

xtrain = pd.read_csv(train_file, index_col=False)
xtrain = xtrain.drop(['Fleet','Cycle','RUL'],axis=1)

# %%
#SHAP Summmary Plot

instance = x_train
instance2 = x_test
explainer = shap.DeepExplainer(model2,instance)
shap_values = explainer.shap_values(instance2)
# Out:
# WARNING:tensorflow:From C:\Users\Asus\anaconda3\lib\site-packages\shap\explainers\tf_utils.py:28: The name tf.keras.backend.get_session is deprecated. Please use tf.compat.v1.keras.backend.get_session instead.

# %%
-05, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i228IHFFCPCI4K1OYZSJI')
#   );
# </script>
# 1 293
# <div id='i1RVYIAKVUQS0PXY5MH49'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.1186816394329071, "outValue": -0.11518780860888, "link": "identity", "featureNames": ["OC1", "OC2", "OC3", "S2", "S3", "S4", "S7", "S8", "S9", "S11", "S12", "S13", "S14", "S15", "S17", "S20", "S21"], "features": {"0": {"effect": 0.00023134858929552138, "value": 0.0}, "1": {"effect": 0.00034987711114808917, "value": 0.0}, "2": {"effect": 0.0002632528485264629, "value": 0.0}, "3": {"effect": 0.0005489148898050189, "value": 0.0}, "4": {"effect": 0.00047989111044444144, "value": 0.0}, "5": {"effect": 0.000672059366479516, "value": 0.0}, "6": {"effect": 8.823939424473792e-05, "value": 0.0}, "7": {"effect": 0.0002272890997119248, "value": 0.0}, "8": {"effect": 6.834143277956173e-05, "value": 0.0}, "9": {"effect": 0.00010549378930591047, "value": 0.0}, "10": {"effect": 6.0532987845363095e-05, "value": 0.0}, "11": {"effect": 0.00022367900237441063, "value": 0.0}, "12": {"effect": 4.670799626182998e-06, "value": 0.0}, "13": {"effect": 7.506732072215527e-05, "value": 0.0}, "14": {"effect": 4.2877923988271505e-05, "value": 0.0}, "15": {"effect": -2.6501251340960152e-05, "value": 0.0}, "16": {"effect": 7.879640907049179e-05, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i1RVYIAKVUQS0PXY5MH49')
#   );
# </script>
# 1 294
# <div id='i1L15IQJ71U8WUSO980DZ'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.1186816394329071, "outValue": -0.11827732710116834, "link": "identity", "featureNames": ["OC1", "OC2", "OC3", "S2", "S3", "S4", "S7", "S8", "S9", "S11", "S12", "S13", "S14", "S15", "S17", "S20", "S21"], "features": {"0": {"effect": 0.00028153686434961855, "value": 0.0}, "1": {"effect": 0.0005590771324932575, "value": 0.0}, "2": {"effect": 0.00021552156249526888, "value": 0.0}, "3": {"effect": 7.325410933844978e-06, "value": 0.0}, "4": {"effect": 0.0007821072358638048, "value": 0.0}, "5": {"effect": 0.00013959608622826636, "value": 0.0}, "6": {"effect": 0.00033059820998460054, "value": 0.0}, "7": {"effect": -1.763585169101134e-05, "value": 0.0}, "8": {"effect": 4.899818577541737e-06, "value": 0.0}, "9": {"effect": -0.0006979492027312517, "value": 0.0}, "10": {"effect": 0.00021773255139123648, "value": 0.0}, "11": {"effect": -0.0005255519645288587, "value": 0.0}, "12": {"effect": -7.521994120907038e-05, "value": 0.0}, "13": {"effect": -0.0007641841657459736, "value": 0.0}, "14": {"effect": -0.0002467306621838361, "value": 0.0}, "15": {"effect": -6.105119246058166e-05, "value": 0.0}, "16": {"effect": 0.0002542404399719089, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i1L15IQJ71U8WUSO980DZ')
#   );
# </script>
# 1 295
# <div id='iSR3JNB9AZUCR68C2C01R'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.1186816394329071, "outValue": -0.1186816394329071, "link": "identity", "featureNames": ["OC1", "OC2", "OC3", "S2", "S3", "S4", "S7", "S8", "S9", "S11", "S12", "S13", "S14", "S15", "S17", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iSR3JNB9AZUCR68C2C01R')
#   );
# </script>
# 1 296
# <div id='iISCW7D5RGIJ129Y254B1'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.1186816394329071, "outValue": -0.1186816394329071, "link": "identity", "featureNames": ["OC1", "OC2", "OC3", "S2", "S3", "S4", "S7", "S8", "S9", "S11", "S12", "S13", "S14", "S15", "S17", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iISCW7D5RGIJ129Y254B1')
#   );
# </script>
# 1 297
# <div id='iJZFF7ASB8Y9RAPRC2YGK'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.1186816394329071, "outValue": -0.1186816394329071, "link": "identity", "featureNames": ["OC1", "OC2", "OC3", "S2", "S3", "S4", "S7", "S8", "S9", "S11", "S12", "S13", "S14", "S15", "S17", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iJZFF7ASB8Y9RAPRC2YGK')
#   );
# </script>
# 1 298
# <div id='iVY7789TN7W25ZNWXIKDX'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.1186816394329071, "outValue": -0.1186816394329071, "link": "identity", "featureNames": ["OC1", "OC2", "OC3", "S2", "S3", "S4", "S7", "S8", "S9", "S11", "S12", "S13", "S14", "S15", "S17", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iVY7789TN7W25ZNWXIKDX')
#   );
# </script>
# 1 299
# <div id='iOGYXHU8LZSPS1AFFHVM8'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.1186816394329071, "outValue": -0.1186816394329071, "link": "identity", "featureNames": ["OC1", "OC2", "OC3", "S2", "S3", "S4", "S7", "S8", "S9", "S11", "S12", "S13", "S14", "S15", "S17", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iOGYXHU8LZSPS1AFFHVM8')
#   );
# </script>
# 1 300
# <div id='iMV35C391RT8YNODSETZV'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.1186816394329071, "outValue": -0.1186816394329071, "link": "identity", "featureNames": ["OC1", "OC2", "OC3", "S2", "S3", "S4", "S7", "S8", "S9", "S11", "S12", "S13", "S14", "S15", "S17", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iMV35C391RT8YNODSETZV')
#   );
# </script>
# 1 301
# <div id='iBAUPII5J057TXVFN1U46'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.1186816394329071, "outValue": -0.1186816394329071, "link": "identity", "featureNames": ["OC1", "OC2", "OC3", "S2", "S3", "S4", "S7", "S8", "S9", "S11", "S12", "S13", "S14", "S15", "S17", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iBAUPII5J057TXVFN1U46')
#   );
# </script>
# 1 302
# <div id='iXO7GCZ5A5VPCDGQK1G4P'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.1186816394329071, "outValue": -0.1186816394329071, "link": "identity", "featureNames": ["OC1", "OC2", "OC3", "S2", "S3", "S4", "S7", "S8", "S9", "S11", "S12", "S13", "S14", "S15", "S17", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i
"link": "identity", "featureNames": ["OC1", "OC2", "OC3", "S2", "S3", "S4", "S7", "S8", "S9", "S11", "S12", "S13", "S14", "S15", "S17", "S20", "S21"], "features": {"0": {"effect": 0.00023134816728997976, "value": 0.0}, "1": {"effect": 0.00034987673279829323, "value": 0.0}, "2": {"effect": 0.0002632523246575147, "value": 0.0}, "3": {"effect": 0.0005489147733896971, "value": 0.0}, "4": {"effect": 0.0004798902082256973, "value": 0.0}, "5": {"effect": 0.0006720587844029069, "value": 0.0}, "6": {"effect": 8.823924872558564e-05, "value": 0.0}, "7": {"effect": 0.00022728856129106134, "value": 0.0}, "8": {"effect": 6.834140367573127e-05, "value": 0.0}, "9": {"effect": 0.00010549429134698585, "value": 0.0}, "10": {"effect": 6.05329405516386e-05, "value": 0.0}, "11": {"effect": 0.0002236791478935629, "value": 0.0}, "12": {"effect": 4.67082145405584e-06, "value": 0.0}, "13": {"effect": 7.506818656111136e-05, "value": 0.0}, "14": {"effect": 4.2877785745076835e-05, "value": 0.0}, "15": {"effect": -2.6501307729631662e-05, "value": 0.0}, "16": {"effect": 7.879621261963621e-05, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iMGLL8BFWK1OB17BVFI4M')
#   );
# </script>
# 18 294
# <div id='iVFKG67T4VVK3SCT6ZVA1'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.1186816394329071, "outValue": -0.11827732962092341, "link": "identity", "featureNames": ["OC1", "OC2", "OC3", "S2", "S3", "S4", "S7", "S8", "S9", "S11", "S12", "S13", "S14", "S15", "S17", "S20", "S21"], "features": {"0": {"effect": 0.00028153619496151805, "value": 0.0}, "1": {"effect": 0.0005590764922089875, "value": 0.0}, "2": {"effect": 0.00021552109683398157, "value": 0.0}, "3": {"effect": 7.3253245318483096e-06, "value": 0.0}, "4": {"effect": 0.0007821060135029256, "value": 0.0}, "5": {"effect": 0.00013959562056697905, "value": 0.0}, "6": {"effect": 0.00033059774432331324, "value": 0.0}, "7": {"effect": -1.7636768461670727e-05, "value": 0.0}, "8": {"effect": 4.899829946225509e-06, "value": 0.0}, "9": {"effect": -0.0006979480385780334, "value": 0.0}, "10": {"effect": 0.00021773237676825374, "value": 0.0}, "11": {"effect": -0.0005255512660369277, "value": 0.0}, "12": {"effect": -7.521982479374856e-05, "value": 0.0}, "13": {"effect": -0.000764182535931468, "value": 0.0}, "14": {"effect": -0.0002467311278451234, "value": 0.0}, "15": {"effect": -6.105123611632735e-05, "value": 0.0}, "16": {"effect": 0.0002542399161029607, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iVFKG67T4VVK3SCT6ZVA1')
#   );
# </script>
# 18 295
# <div id='iD32K8O7XDI1C5B3FSLSW'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.1186816394329071, "outValue": -0.1186816394329071, "link": "identity", "featureNames": ["OC1", "OC2", "OC3", "S2", "S3", "S4", "S7", "S8", "S9", "S11", "S12", "S13", "S14", "S15", "S17", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iD32K8O7XDI1C5B3FSLSW')
#   );
# </script>
# 18 296
# <div id='i3U45TAW9SE2VAV47A1YF'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.1186816394329071, "outValue": -0.1186816394329071, "link": "identity", "featureNames": ["OC1", "OC2", "OC3", "S2", "S3", "S4", "S7", "S8", "S9", "S11", "S12", "S13", "S14", "S15", "S17", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i3U45TAW9SE2VAV47A1YF')
#   );
# </script>
# 18 297
# <div id='iRAOT9FU0EK4HZMGVNROP'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.1186816394329071, "outValue": -0.1186816394329071, "link": "identity", "featureNames": ["OC1", "OC2", "OC3", "S2", "S3", "S4", "S7", "S8", "S9", "S11", "S12", "S13", "S14", "S15", "S17", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iRAOT9FU0EK4HZMGVNROP')
#   );
# </script>
# 18 298
# <div id='i1942OJZVGFA7SYBRU71U'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.1186816394329071, "outValue": -0.1186816394329071, "link": "identity", "featureNames": ["OC1", "OC2", "OC3", "S2", "S3", "S4", "S7", "S8", "S9", "S11", "S12", "S13", "S14", "S15", "S17", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i1942OJZVGFA7SYBRU71U')
#   );
# </script>
# 18 299
# <div id='iJF3YMM9RFXSAA3TFNF86'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.1186816394329071, "outValue": -0.1186816394329071, "link": "identity", "featureNames": ["OC1", "OC2", "OC3", "S2", "S3", "S4", "S7", "S8", "S9", "S11", "S12", "S13", "S14", "S15", "S17", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iJF3YMM9RFXSAA3TFNF86')
#   );
# </script>
# 18 300
# <div id='i9X6BGIR4D4JPGBFHC6DZ'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.1186816394329071, "outValue": -0.1186816394329071, "link": "identity", "featureNames": ["OC1", "OC2", "OC3", "S2", "S3", "S4", "S7", "S8", "S9", "S11", "S12", "S13", "S14", "S15", "S17", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i9X6BGIR4D4JPGBFHC6DZ')
#   );
# </script>
# 18 301
# <div id='iJ0285RQ7H5XJS9CPRI92'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.1186816394329071, "outValue": -0.1186816394329071, "link": "identity", "featureNames": ["OC1", "OC2", "OC3", "S2", "S3", "S4", "S7", "S8", "S9", "S11", "S12", "S13", "S14", "S15", "S17", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iJ0285RQ7H5XJS9CPRI92')
#   );
# </script>
# 18 302
# <div id='iEO74ADCNN9JFZ8VIM8XL'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.1186816394329071, "outValue": -0.1186816394329071, "link": "identity", "featureNames": ["OC1", "OC2", "OC3", "S2", "S3", "S4", "S7", "S8", "S9", "S11", "S12", "S13", "S14", "S15", "S17", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iEO74ADCNN9JFZ8VIM8XL')
#   );
# </script>
# 18 303
# <div id='iNI5QBM01M0S320LZ00HL'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.1186816394329071, "outValue": -0.1186816394329071, "link": "identity", "featureNames": ["OC1", "OC2", "OC3", "S2", "S3", "S4", "S7", "S8", "S9", "S11", "S12", "S13", "S14", "S15", "S17", "S20", "S21"], "features": {}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iNI5QBM01M0S320LZ00HL')
#   );
# </script>
